# %%
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import pprint
import re
from collections import defaultdict
import csv
import codecs
import cerberus
import schema
import sqlite3

# %%
OSM_FILE = "federal_district.osm"
SAMPLE_FILE = "federal_district_sample.osm"

# %% [markdown]
# ### Create sample file from the original Federal District OSM
# ##### Functions
# _From project P3: Limpando os dados do OpenStreetMap. 2. Detalhes do projeto_

# %%
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

# %% [markdown]
# ##### Callers

# %%
k = 10 # Parameter: take every k-th top level element

with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')

# %% [markdown]
# ### Check out the tags occurences on the file
# ##### Functions
# _from lesson "Case Study: OpenStreetMap Data", "3. Quiz: Iterative Treatment". Adapted_

# %%
def count_tags(filename):
    """Count the number of tags in the file"""
    
    tags = defaultdict(int)
        
    for event, elem in ET.iterparse(filename):
            tags[elem.tag] += 1
    return tags

def count_attribs(filename):
    """Count the number of tags attributes in the file"""
    
    attribs = defaultdict(int)
        
    for event, elem in ET.iterparse(filename):
        for tag_attribute in elem.attrib:
                attribs[tag_attribute] += 1
    return attribs

# %% [markdown]
# ##### Callers

# %%
# count the occurrences of tags and tags attributes
print "tags mapping:"
pprint.pprint(dict(count_tags(OSM_FILE)))
print ""
print "attributes mapping:"
pprint.pprint(dict(count_attribs(OSM_FILE)))
# Out:
# tags mapping:
# {'bounds': 1,
#  'member': 6848,
#  'nd': 588469,
#  'node': 446164,
#  'osm': 1,
#  'relation': 957,
#  'tag': 220336,
#  'way': 94703}
#
# attributes mapping:
# {'changeset': 541824,
#  'generator': 1,
#  'id': 541824,
#  'k': 220336,
#  'lat': 446164,
#  'lon': 446164,
#  'maxlat': 1,
#  'maxlon': 1,
#  'minlat': 1,
#  'minlon': 1,
#  'ref': 595317,
#  'role': 6848,
#  'timestamp': 541825,
#  'type': 6848,
#  'uid': 541824,
#  'user': 541824,
#  'v': 220336,
#  'version': 541825}

# %% [markdown]
# ### Check the k attribute values
# ##### Functions

# %%
def count_k_values(filename):
    """Find k values on the tags and count the number of each occurrence"""
    
    k_values = defaultdict(int)
    for _, element in ET.iterparse(filename):
        if (element.tag == 'tag') and ('k' in element.attrib):
                    k_values[element.attrib['k']] += 1
 
    return k_values

# %% [markdown]
# ##### Callers

# %%
# count the occurrences of each "k" attribute  of <tag>
counter = count_k_values(OSM_FILE)
print "number of distinct k attribute: ", len(counter)
pprint.pprint(sorted( ((v,k) for k,v in counter.iteritems()), reverse=True))
# Out:
# number of distinct k attribute:  666
# [(64589, 'highway'),
#  (29440, 'name'),
#  (21011, 'building'),
#  (13639, 'oneway'),
#  (12127, 'source'),
#  (10975, 'surface'),
#  (7018, 'amenity'),
#  (5834, 'maxspeed'),
#  (3381, 'landuse'),
#  (2915, 'noexit'),
#  (2681, 'addr:street'),
#  (2470, 'shop'),
#  (2414, 'leisure'),
#  (2009, 'building:levels'),
#  (1822, 'access'),
#  (1790, 'power'),
#  (1756, 'lanes'),
#  (1651, 'service'),
#  (1350, 'ref'),
#  (1126, 'natural'),
#  (1065, 'addr:city'),
#  (1032, 'addr:housenumber'),
#  (969, 'type'),
#  (966, 'barrier'),
#  (899, 'junction'),
#  (812, 'waterway'),
#  (797, 'note'),
#  (774, 'short_name'),
#  (762, 'phone'),
#  (750, 'addr:postcode'),
#  (698, 'layer'),
#  (697, 'addr:suburb'),
#  (628, 'bicycle'),
#  (624, 'sport'),
#  (613, 'place'),
#  (575, 'inep'),
#  (563, 'operator'),
#  (547, 'bridge'),
#  (542, 'cuisine'),
#  (496, 'crossing'),
#  (491, 'restriction'),
#  (462, 'parking'),
#  (457, 'foot'),
#  (432, 'boundary'),
#  (410, 'addr:place'),
#  (366, 'website'),
#  (353, 'office'),
#  (350, 'aeroway'),
#  (324, 'height'),
#  (314, 'wheelchair'),
#  (314, 'building:part'),
#  (303, 'opening_hours'),
#  (294, 'alt_name'),
#  (276, 'lit'),
#  (276, 'building:material'),
#  (270, 'horse'),
#  (256, 'footway'),
#  (254, 'name:pt'),
#  (253, 'religion'),
#  (237, 'man_made'),
#  (231, 'admin_level'),
#  (227, 'fee'),
#  (224, 'tourism'),
#  (210, 'shelter'),
#  (207, 'loc_name'),
#  (187, 'tunnel'),
#  (187, 'IBGE:CD_ADMINIS'),
#  (181, 'postal_code'),
#  (180, 'reg_name'),
#  (171, 'motor_vehicle'),
#  (158, 'capacity'),
#  (156, 'covered'),
#  (149, 'wikipedia'),
#  (146, 'railway'),
#  (146, 'entrance'),
#  (138, 'denomination'),
#  (126, 'tracktype'),
#  (120, 'addr:housename'),
#  (118, 'is_in'),
#  (117, 'fixme'),
#  (112, 'area'),
#  (111, 'name:en'),
#  (107, 'water'),
#  (101, 'wikidata'),
#  (97, 'atm'),
#  (94, 'level'),
#  (94, 'bicycle_parking'),
#  (91, 'bench'),
#  (89, 'dispensing'),
#  (88, 'traffic_signals'),
#  (88, 'sidewalk'),
#  (74, 'emergency'),
#  (68, 'gauge'),
#  (68, 'electrified'),
#  (66, 'population'),
#  (64, 'segregated'),
#  (63, 'takeaway'),
#  (63, 'network'),
#  (63, 'bus'),
#  (63, 'addr:country'),
#  (62, 'created_by'),
#  (61, 'country'),
#  (60, 'voltage'),
#  (60, 'frequency'),
#  (59, 'cables'),
#  (58, 'description'),
#  (58, 'brand'),
#  (57, 'lanes:psv'),
#  (56, 'seamark:type'),
#  (55, 'boat'),
#  (55, '3dr:type'),
#  (50, 'width'),
#  (50, 'shoulder:right'),
#  (49, 'internet_access'),
#  (48, 'smoking'),
#  (48, 'route'),
#  (46, 'supervised'),
#  (45, 'wires'),
#  (44, 'destination'),
#  (44, 'building:min_level'),
#  (42, 'delivery'),
#  (42, 'crossing_ref'),
#  (39, 'sac_scale'),
#  (38, 'trail_visibility'),
#  (38, 'snowmobile'),
#  (37, 'tower:type'),
#  (37, 'official_name'),
#  (34, 'name:es'),
#  (34, 'design'),
#  (31, 'training'),
#  (31, 'traffic_sign'),
#  (31, 'diet:vegetarian'),
#  (30, 'historic'),
#  (30, 'craft'),
#  (29, 'source:alt_name'),
#  (28, 'oneway:conditional'),
#  (26, 'drive_through'),
#  (26, 'cycleway'),
#  (25, 'motorroad'),
#  (25, 'lanes:bus'),
#  (25, 'addr:full'),
#  (24, 'psv'),
#  (24, 'addr:interpolation'),
#  (24, 'addr:inclusion'),
#  (23, 'sloped_curb'),
#  (23, 'public_transport'),
#  (22, 'traffic_calming'),
#  (21, 'source:name'),
#  (21, 'source:date'),
#  (20, 'usage'),
#  (20, 'seamark:buoy_special_purpose:shape'),
#  (20, 'seamark:buoy_special_purpose:colour'),
#  (20, 'name:fr'),
#  (20, 'is_in:country'),
#  (20, 'ele'),
#  (19, 'name:de'),
#  (19, 'fence_type'),
#  (19, 'email'),
#  (19, 'backrest'),
#  (18, 'name:ar'),
#  (18, 'IBGE:GEOCODIGO'),
#  (17, 'smoothness'),
#  (17, 'payment:telephone_cards'),
#  (17, 'outdoor_seating'),
#  (16, 'is_in:state'),
#  (15, 'recycling:paper'),
#  (15, 'recycling:glass'),
#  (15, 'recycling:cans'),
#  (15, 'old_name'),
#  (15, 'motorcar'),
#  (15, 'is_in:country_code'),
#  (15, 'is_in:continent'),
#  (14, 'name:ja'),
#  (14, 'embankment'),
#  (14, 'diet:vegan'),
#  (13, 'seamark:light:period'),
#  (13, 'seamark:light:colour'),
#  (13, 'seamark:light:character'),
#  (13, 'cutting'),
#  (13, 'administrative'),
#  (12, 'tactile_paving'),
#  (12, 'seamark:topmark:shape'),
#  (12, 'seamark:topmark:colour'),
#  (12, 'parking:lane:both'),
#  (12, 'maxheight'),
#  (11, 'species'),
#  (11, 'cycleway:right'),
#  (11, 'colour'),
#  (10, 'unisex'),
#  (10, 'start_date'),
#  (10, 'name:ru'),
#  (10, 'name:ko'),
#  (10, 'name:bg'),
#  (10, 'leaf_type'),
#  (10, 'flag'),
#  (10, 'basin'),
#  (9, 'seamark:mooring:category'),
#  (9, 'protection_title'),
#  (9, 'protect_class'),
#  (9, 'name:uk'),
#  (9, 'name:ro'),
#  (9, 'name:mr'),
#  (9, 'name:mk'),
#  (9, 'name:lt'),
#  (9, 'name:ka'),
#  (9, 'name:it'),
#  (9, 'name:hy'),
#  (9, 'name:eo'),
#  (9, 'name:be'),
#  (9, 'is_in:state_code'),
#  (9, 'cycleway:left'),
#  (9, 'cre'),
#  (9, 'building:colour'),
#  (8, 'park_ride'),
#  (8, 'name:zh'),
#  (8, 'name:th'),
#  (8, 'name:sr'),
#  (8, 'name:nl'),
#  (8, 'motorcycle'),
#  (8, 'min_height'),
#  (8, 'government'),
#  (8, 'fuel:diesel'),
#  (7, 'sport_1'),
#  (7, 'related_law'),
#  (7, 'ref:CNUC'),
#  (7, 'noname'),
#  (7, 'name:uz'),
#  (7, 'name:tg'),
#  (7, 'name:pl'),
#  (7, 'name:os'),
#  (7, 'name:lv'),
#  (7, 'name:la'),
#  (7, 'name:he'),
#  (7, 'name:gl'),
#  (7, 'name:fa'),
#  (7, 'is_in:region'),
#  (7, 'information'),
#  (7, 'access:conditional'),
#  (6, 'turn:lanes'),
#  (6, 'toilets'),
#  (6, 'ski'),
#  (6, 'site'),
#  (6, 'roof:levels'),
#  (6, 'parking:lane:right'),
#  (6, 'parking:lane:left'),
#  (6, 'name:sv'),
#  (6, 'name:sh'),
#  (6, 'name:ms'),
#  (6, 'name:ia'),
#  (6, 'name:eu'),
#  (6, 'name:ca'),
#  (6, 'leaf_cycle'),
#  (6, 'gay'),
#  (6, 'fuel:octane_95'),
#  (6, 'ford'),
#  (6, 'FIXME'),
#  (5, 'toilets:disposal'),
#  (5, 'name:tr'),
#  (5, 'name:qu'),
#  (5, 'name:id'),
#  (5, 'name:et'),
#  (5, 'mtb:scale:uphill'),
#  (5, 'mtb:scale:imba'),
#  (5, 'mtb:scale'),
#  (5, 'military'),
#  (5, 'local_name'),
#  (5, 'landuse_1'),
#  (5, 'is_in:city'),
#  (5, 'int_name'),
#  (5, 'incline'),
#  (5, 'disused'),
#  (5, 'diet:gluten_free'),
#  (5, 'denotation'),
#  (5, 'club'),
#  (5, 'capacity:disabled'),
#  (5, 'artwork_type'),
#  (4, 'sport_2'),
#  (4, 'social_facility'),
#  (4, 'roof:shape'),
#  (4, 'roof:colour'),
#  (4, 'organic'),
#  (4, 'natural_1'),
#  (4, 'name:yo'),
#  (4, 'name:vi'),
#  (4, 'name:ta'),
#  (4, 'name:sq'),
#  (4, 'name:sk'),
#  (4, 'name:oc'),
#  (4, 'name:io'),
#  (4, 'name:hu'),
#  (4, 'name:hr'),
#  (4, 'name:hi'),
#  (4, 'name:fi'),
#  (4, 'name:el'),
#  (4, 'name:cs'),
#  (4, 'name:bs'),
#  (4, 'location'),
#  (4, 'internet_access:fee'),
#  (4, 'fuel:octane_91'),
#  (4, 'drive_in'),
#  (4, 'display'),
#  (4, 'diplomatic'),
#  (4, 'currency:BRL'),
#  (3, 'tower:construction'),
#  (3, 'toilets:wheelchair'),
#  (3, 'to'),
#  (3, 'timezone'),
#  (3, 'substation'),
#  (3, 'substance'),
#  (3, 'step_count'),
#  (3, 'social_facility:for'),
#  (3, 'second_hand'),
#  (3, 'public_transport:version'),
#  (3, 'pipeline'),
#  (3, 'payment:bitcoin'),
#  (3, 'parking:lane:side'),
#  (3, 'name:ur'),
#  (3, 'name:tt'),
#  (3, 'name:sl'),
#  (3, 'name:pa'),
#  (3, 'name:or'),
#  (3, 'name:mn'),
#  (3, 'name:kw'),
#  (3, 'name:kk'),
#  (3, 'name:is'),
#  (3, 'name:ie'),
#  (3, 'name:gn'),
#  (3, 'name:dv'),
#  (3, 'name:cv'),
#  (3, 'name:co'),
#  (3, 'name:ce'),
#  (3, 'name:br'),
#  (3, 'name:az'),
#  (3, 'name:am'),
#  (3, 'material'),
#  (3, 'local_ref'),
#  (3, 'landcover'),
#  (3, 'icao'),
#  (3, 'fuel:octane_80'),
#  (3, 'from'),
#  (3, 'facebook'),
#  (3, 'drinking_water'),
#  (3, 'construction'),
#  (3, 'architect'),
#  (3, 'ISO3166-2'),
#  (2, 'wikipedia:en'),
#  (2, 'wifi'),
#  (2, 'voltage-high'),
#  (2, 'support'),
#  (2, 'studio'),
#  (2, 'state_capital'),
#  (2, 'sport_3'),
#  (2, 'self_service'),
#  (2, 'seamark:national_information'),
#  (2, 'seamark:name'),
#  (2, 'seamark:light:range'),
#  (2, 'seamark:light:height'),
#  (2, 'seamark:light:group'),
#  (2, 'seamark:landmark:category'),
#  (2, 'seamark:information'),
#  (2, 'room'),
#  (2, 'roof:orientation'),
#  (2, 'reservoir'),
#  (2, 'ramp:wheelchair'),
#  (2, 'proposed'),
#  (2, 'ownership'),
#  (2, 'oneway:bicycle'),
#  (2, 'official_name:en'),
#  (2, 'note:en'),
#  (2, 'name:zh-yue'),
#  (2, 'name:yi'),
#  (2, 'name:wuu'),
#  (2, 'name:vec'),
#  (2, 'name:tl'),
#  (2, 'name:tet'),
#  (2, 'name:sw'),
#  (2, 'name:rm'),
#  (2, 'name:pnb'),
#  (2, 'name:pms'),
#  (2, 'name:no'),
#  (2, 'name:nah'),
#  (2, 'name:mzn'),
#  (2, 'name:my'),
#  (2, 'name:ln'),
#  (2, 'name:lmo'),
#  (2, 'name:lij'),
#  (2, 'name:lez'),
#  (2, 'name:ku'),
#  (2, 'name:kn'),
#  (2, 'name:kl'),
#  (2, 'name:jv'),
#  (2, 'name:ht'),
#  (2, 'name:frp'),
#  (2, 'name:ext'),
#  (2, 'name:eml'),
#  (2, 'name:da'),
#  (2, 'name:cz'),
#  (2, 'name:ckb'),
#  (2, 'name:cbk-zam'),
#  (2, 'name:bpy'),
#  (2, 'name:bo'),
#  (2, 'name:bn'),
#  (2, 'name:be-tarask'),
#  (2, 'name:bat-smg'),
#  (2, 'name:bar'),
#  (2, 'name:ay'),
#  (2, 'name:ast'),
#  (2, 'name:arz'),
#  (2, 'min_level'),
#  (2, 'max_level'),
#  (2, 'male'),
#  (2, 'line'),
#  (2, 'landuse_2'),
#  (2, 'indoor'),
#  (2, 'healthcare'),
#  (2, 'governance_type'),
#  (2, 'generator:source'),
#  (2, 'fuel:ethanol'),
#  (2, 'fuel'),
#  (2, 'driving_side'),
#  (2, 'description:ja'),
#  (2, 'crop'),
#  (2, 'contact:email'),
#  (2, 'communication:radio'),
#  (2, 'clothes'),
#  (2, 'building:levels_1'),
#  (2, 'block'),
#  (2, 'automated'),
#  (2, 'alt_phone'),
#  (2, 'BUI'),
#  (1, 'wikipedia:pt'),
#  (1, 'url'),
#  (1, 'target'),
#  (1, 'sustenance'),
#  (1, 'surveillance:type'),
#  (1, 'surveillance'),
#  (1, 'surface_1'),
#  (1, 'surface:pt'),
#  (1, 'subway'),
#  (1, 'stars'),
#  (1, 'source:url'),
#  (1, 'source:old_name'),
#  (1, 'social_facility_for'),
#  (1, 'service:bicycle:chain_tool'),
#  (1, 'seamark:cable_submarine:category'),
#  (1, 'seamark:buoy_cardinal:shape'),
#  (1, 'seamark:buoy_cardinal:colour_pattern'),
#  (1, 'seamark:buoy_cardinal:colour'),
#  (1, 'seamark:buoy_cardinal:category'),
#  (1, 'recycling:scrap_metal'),
#  (1, 'private'),
#  (1, 'press'),
#  (1, 'population:date'),
#  (1, 'payment:litecoin'),
#  (1, 'payment:debit_cards'),
#  (1, 'payment:credit_cards'),
#  (1, 'old_name:vi'),
#  (1, 'official_name:zh'),
#  (1, 'official_name:vi'),
#  (1, 'official_name:ur'),
#  (1, 'official_name:tr'),
#  (1, 'official_name:te'),
#  (1, 'official_name:ta'),
#  (1, 'official_name:ru'),
#  (1, 'official_name:pl'),
#  (1, 'official_name:pa'),
#  (1, 'official_name:nl'),
#  (1, 'official_name:ms'),
#  (1, 'official_name:ko'),
#  (1, 'official_name:jv'),
#  (1, 'official_name:ja'),
#  (1, 'official_name:it'),
#  (1, 'official_name:hi'),
#  (1, 'official_name:fr'),
#  (1, 'official_name:fa'),
#  (1, 'official_name:es'),
#  (1, 'official_name:eo'),
#  (1, 'official_name:de'),
#  (1, 'official_name:bn'),
#  (1, 'official_name:ar'),
#  (1, 'notes'),
#  (1, 'note:pl'),
#  (1, 'note:de'),
#  (1, 'not_visible'),
#  (1, 'natural_2'),
#  (1, 'name:zu'),
#  (1, 'name:zh-min-nan'),
#  (1, 'name:zh-classical'),
#  (1, 'name:zea'),
#  (1, 'name:za'),
#  (1, 'name:xmf'),
#  (1, 'name:xh'),
#  (1, 'name:xal'),
#  (1, 'name:wo'),
#  (1, 'name:war'),
#  (1, 'name:wa'),
#  (1, 'name:vo'),
#  (1, 'name:vls'),
#  (1, 'name:vep'),
#  (1, 'name:ug'),
#  (1, 'name:tzl'),
#  (1, 'name:ty'),
#  (1, 'name:tok'),
#  (1, 'name:tk'),
#  (1, 'name:te'),
#  (1, 'name:szl'),
#  (1, 'name:su'),
#  (1, 'name:stq'),
#  (1, 'name:st'),
#  (1, 'name:srn'),
#  (1, 'name:so'),
#  (1, 'name:se'),
#  (1, 'name:sco'),
#  (1, 'name:scn'),
#  (1, 'name:sc'),
#  (1, 'name:sah'),
#  (1, 'name:sa'),
#  (1, 'name:rw'),
#  (1, 'name:rue'),
#  (1, 'name:roa-tara'),
#  (1, 'name:rn'),
#  (1, 'name:rmy'),
#  (1, 'name:ps'),
#  (1, 'name:pih'),
#  (1, 'name:pdc'),
#  (1, 'name:pcd'),
#  (1, 'name:pap'),
#  (1, 'name:pam'),
#  (1, 'name:pag'),
#  (1, 'name:nv'),
#  (1, 'name:nrm'),
#  (1, 'name:nov'),
#  (1, 'name:nn'),
#  (1, 'name:new'),
#  (1, 'name:ne'),
#  (1, 'name:nds-nl'),
#  (1, 'name:nds'),
#  (1, 'name:nap'),
#  (1, 'name:na'),
#  (1, 'name:mwl'),
#  (1, 'name:mt'),
#  (1, 'name:mrj'),
#  (1, 'name:ml'),
#  (1, 'name:mi'),
#  (1, 'name:mhr'),
#  (1, 'name:mg'),
#  (1, 'name:mdf'),
#  (1, 'name:ltg'),
#  (1, 'name:li'),
#  (1, 'name:lb'),
#  (1, 'name:lad'),
#  (1, 'name:ky'),
#  (1, 'name:kv'),
#  (1, 'name:krc'),
#  (1, 'name:km'),
#  (1, 'name:ki'),
#  (1, 'name:kg'),
#  (1, 'name:kbd'),
#  (1, 'name:kab'),
#  (1, 'name:kaa'),
#  (1, 'name:jbo'),
#  (1, 'name:ilo'),
#  (1, 'name:ig'),
#  (1, 'name:hsb'),
#  (1, 'name:hif'),
#  (1, 'name:haw'),
#  (1, 'name:hak'),
#  (1, 'name:gv'),
#  (1, 'name:gu'),
#  (1, 'name:gd'),
#  (1, 'name:gan'),
#  (1, 'name:gag'),
#  (1, 'name:ga'),
#  (1, 'name:fy'),
#  (1, 'name:fur'),
#  (1, 'name:frr'),
#  (1, 'name:fo'),
#  (1, 'name:fiu-vro'),
#  (1, 'name:ee'),
#  (1, 'name:dz'),
#  (1, 'name:dsb'),
#  (1, 'name:diq'),
#  (1, 'name:cy'),
#  (1, 'name:cu'),
#  (1, 'name:csb'),
#  (1, 'name:crh'),
#  (1, 'name:chr'),
#  (1, 'name:ceb'),
#  (1, 'name:cdo'),
#  (1, 'name:bxr'),
#  (1, 'name:bm'),
#  (1, 'name:bi'),
#  (1, 'name:bcl'),
#  (1, 'name:ba'),
#  (1, 'name:as'),
#  (1, 'name:arc'),
#  (1, 'name:ang'),
#  (1, 'name:an'),
#  (1, 'name:als'),
#  (1, 'name:af'),
#  (1, 'name:ace'),
#  (1, 'name:ab'),
#  (1, 'microbrewery'),
#  (1, 'maxwidth'),
#  (1, 'lift_gate:type'),
#  (1, 'leisure_2'),
#  (1, 'leisure_1'),
#  (1, 'layer_1'),
#  (1, 'lawyer'),
#  (1, 'landmark'),
#  (1, 'inscription'),
#  (1, 'industrial'),
#  (1, 'iata'),
#  (1, 'hoops'),
#  (1, 'health_facility:type'),
#  (1, 'handrail'),
#  (1, 'golf:par'),
#  (1, 'golf:course'),
#  (1, 'golf'),
#  (1, 'genus'),
#  (1, 'generator:method'),
#  (1, 'fuel:biogas'),
#  (1, 'fuel:biodiesel'),
#  (1, 'free_flying:site'),
#  (1, 'floor:material'),
#  (1, 'flagpole'),
#  (1, 'flag:type'),
#  (1, 'flag:country'),
#  (1, 'fire_hydrant:type'),
#  (1, 'female'),
#  (1, 'fax'),
#  (1, u'endere\xe7o'),
#  (1, 'disused:amenity'),
#  (1, 'direction'),
#  (1, 'diet:lactose_free'),
#  (1, 'diameter_crown'),
#  (1, 'destination:lanes'),
#  (1, 'currency:USD'),
#  (1, 'currency'),
#  (1, 'content'),
#  (1, 'contact:instagram'),
#  (1, 'collection_times'),
#  (1, 'coffee'),
#  (1, 'clock'),
#  (1, 'capital_ISO3166-1'),
#  (1, 'capital'),
#  (1, 'capacity:women'),
#  (1, 'button_operated'),
#  (1, 'bridge:structure'),
#  (1, 'border_type'),
#  (1, 'bollard'),
#  (1, 'artist_name'),
#  (1, 'artist'),
#  (1, 'alt_name:vi'),
#  (1, 'alt_name:ru'),
#  (1, 'alt_name:en'),
#  (1, 'aerodrome:type'),
#  (1, 'addr:unit'),
#  (1, 'abbr_name'),
#  (1, 'ISO3166-1:numeric'),
#  (1, 'ISO3166-1:alpha3'),
#  (1, 'ISO3166-1:alpha2'),
#  (1, 'ISO3166-1'),
#  (1, 'GEOCODIG_M'),
#  (1, 'GEOCODIG_D'),
#  (1, '2016olympicgames')]

# %% [markdown]
# ### Note:
# * every tag with lat has a long attribute
# * changeset, id, uid and user matches, timestamp and version matches, but (changeset, id, uid and user) and (timestamp and version) does not (541824 != 541825)
#     * _this is due to the "osm" tag, that has the version and timestamp but is about the OSM export file, not the inserted tag itself_
# * k and v attributes matches
# * total ref matches with total (nd and member). nd and member are the tags that have ref attributes
# * every tag "tag" has a "k" and "v" attribute

# %% [markdown]
# ### Check for certain patterns in the tags attributes
#
# ##### Regular Expressions

# %%
lower = re.compile(r'^([a-z]+_?[a-z]*)*[a-z]+$') #sequence of lower words that can be spaced with _ (no repetitions) and no _ at the beginning end of the string. 
                                                 #Ex: code_for_udacity <- match
                                                 # code__for_udacity or code_for_udacity_ <- does not match

lower_colon = re.compile(r'^(([a-z]+_?[a-z]*)*[a-z]+:)+(([a-z]+_?[a-z]*)*[a-z]+)$') # same of lower with : ou multiple
                                                                                            # Ex: code:for:udacity,  <- match
                                                                                            # code::for_udacity <- does not match

problemchars = re.compile(r'[^a-zA-Z0-9_\s]')
numbers = re.compile(r'^([0-9])*$')
upper = re.compile(r'^([A-Z]+_?[A-Z]*)*[A-Z]+$')

# %% [markdown]
# ##### Functions
# _from lesson "Case Study: OpenStreetMap Data", "6. Quiz: Tags types". Adapted_

# %%
def key_type(element, keys, attribute):
    """Get the number of ocurrences of regular expressions patterns in the tags attributes"""
    
    if attribute in element.attrib:       
        attribute_value = element.attrib[attribute]
   
        if lower.search(attribute_value):
            keys['lower'] += 1
        elif lower_colon.search(attribute_value):
            keys['lower_colon'] += 1
        elif upper.search(attribute_value):
            keys['upper'] += 1
        elif numbers.search(attribute_value):
            keys['numbers'] += 1
        elif problemchars.search(attribute_value):
            keys['problemchars'] += 1
        else:
            keys['others'] += 1
                 
    return keys

def get_attr_list(filename):
    """Get the list of attributes on the xml file tags"""
    
    attr_list = set()
    for _, element in ET.iterparse(filename):
        for attribute in element.attrib:
            attr_list.add(attribute)
        
    return attr_list

def process_map(filename):
    """Create a list of dictionaries with the regular expressions patterns on the tags attributes"""
    
    keys_list = defaultdict(list)
    attributes = get_attr_list(filename)
    
    for attribute in attributes:
        keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "numbers" : 0, "upper": 0, "others" : 0}
        for _, element in ET.iterparse(filename):
            search = key_type(element, keys, attribute)
        keys_list[attribute] = search

    return keys_list

# %% [markdown]
# ##### Callers

# %%
# check for certain patterns in the tags attributes
keys = process_map(OSM_FILE)
pprint.pprint(dict(keys))
# Out:
# {'changeset': {'lower': 0,
#                'lower_colon': 0,
#                'numbers': 541824,
#                'others': 0,
#                'problemchars': 0,
#                'upper': 0},
#  'generator': {'lower': 0,
#                'lower_colon': 0,
#                'numbers': 0,
#                'others': 0,
#                'problemchars': 1,
#                'upper': 0},
#  'id': {'lower': 0,
#         'lower_colon': 0,
#         'numbers': 541824,
#         'others': 0,
#         'problemchars': 0,
#         'upper': 0},
#  'k': {'lower': 208547,
#        'lower_colon': 11438,
#        'numbers': 0,
#        'others': 30,
#        'problemchars': 311,
#        'upper': 10},
#  'lat': {'lower': 0,
#          'lower_colon': 0,
#          'numbers': 0,
#          'others': 0,
#          'problemchars': 446164,
#          'upper': 0},
#  'lon': {'lower': 0,
#          'lower_colon': 0,
#          'numbers': 0,
#          'others': 0,
#          'problemchars': 446164,
#          'upper': 0},
#  'maxlat': {'lower': 0,
#             'lower_colon': 0,
#             'numbers': 0,
#             'others': 0,
#             'problemchars': 1,
#             'upper': 0},
#  'maxlon': {'lower': 0,
#             'lower_colon': 0,
#             'numbers': 0,
#             'others': 0,
#             'problemchars': 1,
#             'upper': 0},
#  'minlat': {'lower': 0,
#             'lower_colon': 0,
#             'numbers': 0,
#             'others': 0,
#             'problemchars': 1,
#             'upper': 0},
#  'minlon': {'lower': 0,
#             'lower_colon': 0,
#             'numbers': 0,
#             'others': 0,
#             'problemchars': 1,
#             'upper': 0},
#  'ref': {'lower': 0,
#          'lower_colon': 0,
#          'numbers': 595317,
#          'others': 0,
#          'problemchars': 0,
#          'upper': 0},
#  'role': {'lower': 4793,
#           'lower_colon': 0,
#           'numbers': 2052,
#           'others': 3,
#           'problemchars': 0,
#           'upper': 0},
#  'timestamp': {'lower': 0,
#                'lower_colon': 0,
#                'numbers': 0,
#                'others': 0,
#                'problemchars': 541825,
#                'upper': 0},
#  'type': {'lower': 6848,
#           'lower_colon': 0,
#           'numbers': 0,
#           'others': 0,
#           'problemchars': 0,
#           'upper': 0},
#  'uid': {'lower': 0,
#          'lower_colon': 0,
#          'numbers': 541824,
#          'others': 0,
#          'problemchars': 0,
#          'upper': 0},
#  'user': {'lower': 281656,
#           'lower_colon': 0,
#           'numbers': 1,
#           'others': 242250,
#           'problemchars': 17883,
#           'upper': 34},
#  'v': {'lower': 151522,
#        'lower_colon': 6,
#        'numbers': 13508,
#        'others': 35489,
#        'problemchars': 17435,
#        'upper': 2376},
#  'version': {'lower': 0,
#              'lower_colon': 0,
#              'numbers': 541824,
#              'others': 0,
#              'problemchars': 1,
#              'upper': 0}}

# %% [markdown]
# ### Check potential problems on attributes values
#
# ##### Functions

# %%
def get_attr_re_test(filename, attribute, re_test):
    """Return distinct list (set) of the selected attribute that matches a regular expression"""
    
    list_attr_re_test = set()
    
    for _, element in ET.iterparse(filename):
        if attribute in element.attrib: 
            if re_test.search(element.attrib[attribute]):
                    list_attr_re_test.add(element.attrib[attribute])
        
    return list_attr_re_test

def count_char_re_test(filename, attribute, re_test): 
    """Count the number of occurrences of the matched character on regular expression"""
    
    count_char_re_test = defaultdict(int)
    
    for _, element in ET.iterparse(filename):
            if attribute in element.attrib: 
                if re_test.search(element.attrib[attribute]):
                    m = re_test.findall(element.attrib[attribute])
                    for n in m:
                        count_char_re_test[n] += 1
        
    return count_char_re_test

def print_sorted_dict_by_value(d):
    """Print dictionary sorted by value"""
    
    sort = sorted( ((v,k) for k,v in d.iteritems()), reverse=True)
    for item in sort:
        print item[0], " : ", item[1]

# %% [markdown]
# ##### Callers

# %%
# get the attribute value for given regular expression
print "generator attribute problemchars value: ", get_attr_re_test(OSM_FILE, "generator", problemchars)
print "version attribute problemchars value: ", get_attr_re_test(OSM_FILE, "version", problemchars)
print "user attribute number value: ", get_attr_re_test(OSM_FILE, "user", numbers)
# Out:
# generator attribute problemchars value:  set(['osmconvert 0.8.5'])
# version attribute problemchars value:  set(['0.6'])
# user attribute number value:  set(['2058'])

# %%
# get the number of occurrences of each charactere of "user" attribute that matches problemchars regular expression
users_problemchars_count = count_char_re_test(OSM_FILE, "user", problemchars)
print "users problemchars values count: " 
print_sorted_dict_by_value(users_problemchars_count)
# Out:
# users problemchars values count:
# 8700  :  í
# 5170  :  á
# 2151  :  !
# 711  :  -
# 693  :  เ
# 507  :  é
# 462  :  и
# 281  :  ú
# 232  :  я
# 231  :  ວ
# 231  :  э
# 231  :  Δ
# 231  :  ʟ
# 231  :  ɢ
# 66  :  š
# 37  :  Í
# 25  :  ô
# 18  :  ç
# 17  :  ã
# 4  :  е
# 2  :  с
# 2  :  р
# 2  :  н
# 2  :  л
# 2  :  й
# 2  :  А
# 1  :  у
# 1  :  о
# 1  :  к
# 1  :  д
# 1  :  г
# 1  :  в
# 1  :  б
# 1  :  а
# 1  :  П
# 1  :  З
# 1  :  â

# %%
# get the number of occurrences of each charactere of "v" attribute that matches problemchars regular expression
v_problemchars_count = count_char_re_test(OSM_FILE, "v", problemchars)
print "v problemchars values count: " 
print_sorted_dict_by_value(v_problemchars_count)
# Out:
# v problemchars values count:
# 6582  :  -
# 2333  :  í
# 2177  :  á
# 2101  :  /
# 2038  :  ã
# 1990  :  .
# 1648  :  :
# 1454  :  ;
# 1238  :  ç
# 947  :  é
# 810  :  ó
# 705  :  â
# 662  :  ú
# 397  :  ,
# 362  :  +
# 342  :  Á
# 290  :  ô
# 281  :  (
# 280  :  ê
# 280  :  )
# 178  :  õ
# 147  :  а
# 136  :  и
# 127  :  '
# 124  :  ª
# 111  :  р
# 83  :  л
# 77  :  ا
# 70  :  з
# 61  :  н
# 61  :  е
# 60  :  Б
# 57  :  @
# 51  :  ر
# 47  :  ل
# 46  :  о
# 44  :  à
# 39  :  Â
# 38  :  с
# 38  :  &
# 35  :  я
# 35  :  Ó
# 34  :  É
# 34  :  º
# 30  :  ա
# 30  :  д
# 29  :  ی
# 29  :  ي
# 27  :  ा
# 27  :  |
# 26  :  ب
# 26  :  %
# 24  :  ი
# 24  :  і
# 24  :  г
# 24  :  "
# 21  :  س
# 20  :  ز
# 20  :  т
# 19  :  ა
# 18  :  ف
# 18  :  Í
# 18  :  #
# 17  :  ة
# 17  :  к
# 15  :  й
# 14  :  რ
# 14  :  ्
# 14  :  ր
# 13  :  ி
# 13  :  ि
# 13  :  י
# 13  :  ն
# 13  :  Ф
# 12  :  र
# 12  :  य
# 12  :  م
# 12  :  у
# 11  :  ლ
# 11  :  ე
# 11  :  Ã
# 11  :  ?
# 10  :  西
# 10  :  巴
# 10  :  ร
# 10  :  া
# 10  :  स
# 10  :  ल
# 10  :  ज
# 10  :  א
# 10  :  ь
# 10  :  в
# 10  :  $
# 9  :  เ
# 9  :  ্
# 9  :  و
# 9  :  ن
# 9  :  ի
# 8  :  ་
# 8  :  ్
# 8  :  ी
# 8  :  ब
# 8  :  د
# 8  :  ר
# 8  :  ז
# 8  :  ы
# 8  :  М
# 8  :  Ж
# 8  :  Г
# 8  :  α
# 7  :  邦
# 7  :  ラ
# 7  :  ジ
# 7  :  ்
# 7  :  ੀ
# 7  :  র
# 7  :  ל
# 7  :  ë
# 7  :  ä
# 7  :  Ô
# 7  :  !
# 6  :  ア
# 6  :  –
# 6  :  ს
# 6  :  ო
# 6  :  ี
# 6  :  า
# 6  :  ส
# 6  :  ர
# 6  :  ச
# 6  :  ਾ
# 6  :  ি
# 6  :  ব
# 6  :  ग
# 6  :  ه
# 6  :  շ
# 6  :  յ
# 6  :  ј
# 6  :  э
# 6  :  ė
# 6  :  ü
# 6  :  Ú
# 5  :  방
# 5  :  라
# 5  :  ブ
# 5  :  タ
# 5  :  ิ
# 5  :  ล
# 5  :  ต
# 5  :  ి
# 5  :  ି
# 5  :  ਰ
# 5  :  ਜ
# 5  :  ল
# 5  :  ত
# 5  :  জ
# 5  :  ق
# 5  :  ج
# 5  :  ב
# 5  :  п
# 5  :  Ц
# 5  :  λ
# 5  :  ö
# 5  :  ñ
# 5  :  °
# 4  :  질
# 4  :  브
# 4  :  連
# 4  :  利
# 4  :  ン
# 4  :  ル
# 4  :  ス
# 4  :  よ
# 4  :  に
# 4  :  ნ
# 4  :  ზ
# 4  :  ბ
# 4  :  း
# 4  :  ུ
# 4  :  ི
# 4  :  ย
# 4  :  ด
# 4  :  ್
# 4  :  ర
# 4  :  ல
# 4  :  ய
# 4  :  ப
# 4  :  ட
# 4  :  க
# 4  :  ੍
# 4  :  ਼
# 4  :  ਲ
# 4  :  ਬ
# 4  :  म
# 4  :  ط
# 4  :  ت
# 4  :  ה
# 4  :  տ
# 4  :  ջ
# 4  :  լ
# 4  :  х
# 4  :  С
# 4  :  П
# 4  :  ρ
# 4  :  ί
# 4  :  î
# 4  :  è
# 4  :  Ç
# 4  :  =
# 3  :  연
# 3  :  아
# 3  :  스
# 3  :  斯
# 3  :  亞
# 3  :  ー
# 3  :  ・
# 3  :  リ
# 3  :  ’
# 3  :  ዚ
# 3  :  ብ
# 3  :  ራ
# 3  :  უ
# 3  :  მ
# 3  :  თ
# 3  :  დ
# 3  :  გ
# 3  :  ာ
# 3  :  ལ
# 3  :  ར
# 3  :  ์
# 3  :  ั
# 3  :  บ
# 3  :  น
# 3  :  ซ
# 3  :  ก
# 3  :  ె
# 3  :  ల
# 3  :  బ
# 3  :  ா
# 3  :  த
# 3  :  ୍
# 3  :  ା
# 3  :  ଲ
# 3  :  ର
# 3  :  ବ
# 3  :  স
# 3  :  য
# 3  :  े
# 3  :  ़
# 3  :  श
# 3  :  व
# 3  :  भ
# 3  :  न
# 3  :  झ
# 3  :  क
# 3  :  ް
# 3  :  ި
# 3  :  ލ
# 3  :  ބ
# 3  :  ރ
# 3  :  ە
# 3  :  ہ
# 3  :  غ
# 3  :  ع
# 3  :  إ
# 3  :  ס
# 3  :  מ
# 3  :  ו
# 3  :  ս
# 3  :  զ
# 3  :  ե
# 3  :  Բ
# 3  :  ё
# 3  :  ъ
# 3  :  ш
# 3  :  ч
# 3  :  б
# 3  :  Р
# 3  :  ι
# 3  :  ζ
# 3  :  č
# 3  :  ý
# 3  :  *
# 2  :  지
# 2  :  이
# 2  :  리
# 2  :  국
# 2  :  구
# 2  :  防
# 2  :  轄
# 2  :  設
# 2  :  訓
# 2  :  聯
# 2  :  置
# 2  :  練
# 2  :  直
# 2  :  用
# 2  :  消
# 2  :  援
# 2  :  国
# 2  :  和
# 2  :  區
# 2  :  区
# 2  :  助
# 2  :  共
# 2  :  亚
# 2  :  ワ
# 2  :  ポ
# 2  :  ナ
# 2  :  ト
# 2  :  ッ
# 2  :  チ
# 2  :  グ
# 2  :  ガ
# 2  :  イ
# 2  :  れ
# 2  :  る
# 2  :  て
# 2  :  っ
# 2  :  た
# 2  :  さ
# 2  :  ​
# 2  :  ậ
# 2  :  ያ
# 2  :  ሊ
# 2  :  ქ
# 2  :  ფ
# 2  :  ვ
# 2  :  ေ
# 2  :  ု
# 2  :  ိ
# 2  :  ရ
# 2  :  ဘ
# 2  :  င
# 2  :  ཱ
# 2  :  ཟ
# 2  :  པ
# 2  :  །
# 2  :  โ
# 2  :  อ
# 2  :  ม
# 2  :  ฟ
# 2  :  ท
# 2  :  ಿ
# 2  :  ಾ
# 2  :  ಲ
# 2  :  ರ
# 2  :  ಬ
# 2  :  ఫ
# 2  :  జ
# 2  :  ே
# 2  :  ூ
# 2  :  ு
# 2  :  ସ
# 2  :  ଆ
# 2  :  ਆ
# 2  :  ী
# 2  :  ়
# 2  :  ो
# 2  :  ह
# 2  :  त
# 2  :  ީ
# 2  :  ާ
# 2  :  ަ
# 2  :  ސ
# 2  :  އ
# 2  :  گ
# 2  :  ڕ
# 2  :  ى
# 2  :  ك
# 2  :  ح
# 2  :  أ
# 2  :  פ
# 2  :  ח
# 2  :  ד
# 2  :  և
# 2  :  ո
# 2  :  ծ
# 2  :  Դ
# 2  :  ә
# 2  :  ў
# 2  :  ї
# 2  :  м
# 2  :  Ю
# 2  :  π
# 2  :  ε
# 2  :  Μ
# 2  :  ų
# 2  :  ř
# 2  :  ī
# 2  :  ğ
# 2  :  ā
# 2  :  û
# 2  :  ´
# 1  :  ）
# 1  :  （
# 1  :  ﻿
# 1  :  화
# 1  :  한
# 1  :  중
# 1  :  제
# 1  :  서
# 1  :  사
# 1  :  미
# 1  :  동
# 1  :  대
# 1  :  남
# 1  :  나
# 1  :  관
# 1  :  공
# 1  :  고
# 1  :  ꙗ
# 1  :  ꙁ
# 1  :  館
# 1  :  部
# 1  :  警
# 1  :  联
# 1  :  纳
# 1  :  米
# 1  :  研
# 1  :  本
# 1  :  日
# 1  :  拉
# 1  :  所
# 1  :  戈
# 1  :  察
# 1  :  大
# 1  :  員
# 1  :  吉
# 1  :  南
# 1  :  務
# 1  :  公
# 1  :  修
# 1  :  使
# 1  :  东
# 1  :  ロ
# 1  :  メ
# 1  :  ミ
# 1  :  フ
# 1  :  ピ
# 1  :  ゴ
# 1  :  カ
# 1  :  エ
# 1  :  ェ
# 1  :  ‎
# 1  :  ộ
# 1  :  ẽ
# 1  :  ្
# 1  :  ៊
# 1  :  េ
# 1  :  ី
# 1  :  ស
# 1  :  ល
# 1  :  រ
# 1  :  ប
# 1  :  Ꮟ
# 1  :  Ꮖ
# 1  :  Ꮅ
# 1  :  ል
# 1  :  ხ
# 1  :  ც
# 1  :  ღ
# 1  :  ტ
# 1  :  ჟ
# 1  :  ြ
# 1  :  ်
# 1  :  ့
# 1  :  ံ
# 1  :  ီ
# 1  :  လ
# 1  :  ယ
# 1  :  မ
# 1  :  န
# 1  :  ဇ
# 1  :  စ
# 1  :  ཡ
# 1  :  ཛ
# 1  :  བ
# 1  :  ไ
# 1  :  ู
# 1  :  ะ
# 1  :  ศ
# 1  :  ป
# 1  :  ถ
# 1  :  ช
# 1  :  ൽ
# 1  :  ്
# 1  :  ീ
# 1  :  സ
# 1  :  ര
# 1  :  ബ
# 1  :  ೆ
# 1  :  ಸ
# 1  :  ಯ
# 1  :  ಜ
# 1  :  ే
# 1  :  వ
# 1  :  ప
# 1  :  డ
# 1  :  ట
# 1  :  క
# 1  :  ఆ
# 1  :  ம
# 1  :  ந
# 1  :  இ
# 1  :  ଜ
# 1  :  ્
# 1  :  િ
# 1  :  ા
# 1  :  લ
# 1  :  ર
# 1  :  બ
# 1  :  ઝ
# 1  :  ੰ
# 1  :  ਸ
# 1  :  ਦ
# 1  :  ਣ
# 1  :  ਘ
# 1  :  ਗ
# 1  :  ৰ
# 1  :  ূ
# 1  :  ু
# 1  :  ভ
# 1  :  প
# 1  :  ন
# 1  :  দ
# 1  :  ক
# 1  :  ং
# 1  :  ू
# 1  :  प
# 1  :  ध
# 1  :  द
# 1  :  ण
# 1  :  च
# 1  :  घ
# 1  :  ए
# 1  :  ई
# 1  :  इ
# 1  :  आ
# 1  :  ं
# 1  :  ެ
# 1  :  ު
# 1  :  ޒ
# 1  :  ܪ
# 1  :  ܠ
# 1  :  ܝ
# 1  :  ܙ
# 1  :  ܒ
# 1  :  ܐ
# 1  :  ص
# 1  :  ئ
# 1  :  נ
# 1  :  ג
# 1  :  վ
# 1  :  մ
# 1  :  Մ
# 1  :  Հ
# 1  :  Կ
# 1  :  Ժ
# 1  :  Գ
# 1  :  ц
# 1  :  Ч
# 1  :  О
# 1  :  Н
# 1  :  А
# 1  :  Ј
# 1  :  τ
# 1  :  σ
# 1  :  ς
# 1  :  η
# 1  :  δ
# 1  :  β
# 1  :  ά
# 1  :  Π
# 1  :  Ε
# 1  :  Β
# 1  :  ț
# 1  :  ž
# 1  :  Ž
# 1  :  ż
# 1  :  š
# 1  :  ł
# 1  :  ľ
# 1  :  Ĝ
# 1  :  ì
# 1  :  Ö
# 1  :  Ì
# 1  :  Ê
# 1  :  È
# 1  :  ]
# 1  :  >

# %%
# get the value of the "k" attribute that matches the upper regular expression
print "k attribute uppers value: ", get_attr_re_test(OSM_FILE, "k", upper)

# get the number of occurrences of each charactere of "k" attribute that matches problemchars regular expression
k_problemchars_count = count_char_re_test(OSM_FILE, "k", problemchars)
print "k problemchars values count: " 
print_sorted_dict_by_value(k_problemchars_count)
    
# find "k" attribute with problemchar
for _, element in ET.iterparse(OSM_FILE):
    if "k" in element.attrib:
        if (u'\xe7' in element.attrib["k"]) or ('-' in element.attrib["k"]):
            print "k with problemchar: ", element.attrib["k"]
# Out:
# k attribute uppers value:  set(['GEOCODIG_D', 'GEOCODIG_M', 'FIXME', 'BUI'])
# k problemchars values count:
# 11904  :  :
# 24  :  -
# 1  :  ç
# k with problemchar:  name:zh-yue
# k with problemchar:  name:bat-smg
# k with problemchar:  name:cbk-zam
# k with problemchar:  name:be-tarask
# k with problemchar:  capital_ISO3166-1
# k with problemchar:  endereço
# k with problemchar:  voltage-high
# k with problemchar:  voltage-high
# k with problemchar:  ISO3166-1
# k with problemchar:  ISO3166-1:alpha2
# k with problemchar:  ISO3166-1:alpha3
# k with problemchar:  ISO3166-1:numeric
# k with problemchar:  name:bat-smg
# k with problemchar:  name:be-tarask
# k with problemchar:  name:cbk-zam
# k with problemchar:  name:fiu-vro
# k with problemchar:  name:nds-nl
# k with problemchar:  name:roa-tara
# k with problemchar:  name:zh-classical
# k with problemchar:  name:zh-min-nan
# k with problemchar:  name:zh-yue
# k with problemchar:  ISO3166-2
# k with problemchar:  ISO3166-2
# k with problemchar:  ISO3166-2

# %% [markdown]
# ### Note:
# * minlat, minlon, maxlat, maxlon, lat, lon problemchars relative to minus (-) and point (.). Not really a problem
# * timestamp problemchars due to minus (-)
# * changeset, id, uid, ref, type as expected
# * "v" has several problemchars and upper, but it is like a free field to the value of the key
# * generator and version problemchars are due to dot(.)
# * there is a user with just numbers, the user 2058
# * there are a lot of users with special caracteres but it is not a big deal since users are a free form of creation and people like to use special characteres in their nicknames
# * "k" problemchars are due to names and value 'endereço'
# * the "v" value has a lot of problemchars. Most of them are portuguese and other languages specific characteres. Our focus will be on these characteres:
#
# / . : ; , + ( ) ' &amp; " # $ ! = ] >
#     * / used mainly for web pages. found in addresses (not a problem), opening hours (24/7) (not a problem), multivalorated telephones
#     * .(dot) used in web pages, e-mails, addresses, abbreviations, zipcodes
#     * : used for wikipedia, websites, hours
#     * ; used as separator
#     * , used as separator
#     * + used on telephones and {network : + bike}
#     * ( used on telephones, wikipedia and details
#     * ) used on telephones, wikipedia and details
#     * ' mainly on english names
#     * & places names
#     * " details
#     * # colors
#     * (dollar) prices
#     * ! notes
#     * = webpages
#     * ] typo: Datacenter Banco do Brasil]
#     * > typo: Esta via NUNCA é usada no sentido da EPCL->EPIA!

# %% [markdown]
# ### Check attributes values with problemchar
# ##### Functions

# %%
def get_attr_values(filename, attribute, character):
    """Get attribute values by character"""
    
    list_attr_values = []
    for _, element in ET.iterparse(filename):
        if attribute in element.attrib:
            if character in element.attrib[attribute]:
                list_attr_values.append(element.attrib[attribute])
    return list_attr_values

# %% [markdown]
# ##### Callers

# %%
# define chars to be checked
problem_chars = ['/', '.', ':', ';', ',', '+', '(',')', "'", '&', '"', '#', "$", "!", "=", "]", ">"]

# get the attribute values that has the problem_chars
for problem_char in problem_chars:
    print problem_char, " ---------------------------------------------"
    for value in get_attr_values(OSM_FILE, "v", problem_char):
        print value
# Out:
# /  ---------------------------------------------
# http://upload.wikimedia.org/wikipedia/commons/3/3c/Bandeira_do_Distrito_Federal_%28Brasil%29.svg
# http://www.brasilia.df.gov.br/
# http://www.formosa.go.gov.br
# http://upload.wikimedia.org/wikipedia/commons/d/dc/Bandeira_de_Taguatinga_%28DF%29.svg
# http://www.taguatinga.df.gov.br/
# http://novageracao.academiaweb.com.br
# http://www.novositedogiraffas.com
# http://www.supercei.com.br
# 608/609 Norte
# Escola Parque EQS 210/211 Sul
# http://www.popobrasil.com
# http://www.correios.com.br
# 24/7
# http://www.pisttache.com.br
# http://www.tuttisapori.com.br
# http://www.tokyorestaurante.com.br
# http://www.mansoori.com.br/portugues/localizacao.cfm
# http://www.mansoori.com.br/portugues/localizacao.cfm
# http://www.icesp.br/
# http://www.faculdadedarwin.com
# http://www.facitec.br/
# http://www.anhanguera.com/graduacao/localidades/brasilia_jk.php
# Ligia Artesanato / Capim Dourado
# http://cinecultura.com.br/
# http://www.hotelstpaul.com.br
# http://itaucinemas.com.br
# modulo 24/26
# 3399-2031/ 3064
# 24/7
# 24/7
# http://www.companhiadaterra.com/
# http://www.ciadaterra.com
# http://www.drograriarosario.com.br
# http://www.drograriarosario.com.br
# http://bsb.aero/
# http://www.giraffas.com.br/
# http://www.americanas.com
# http://upload.wikimedia.org/wikipedia/commons/0/08/Bandeira_de_Ceil%C3%A2ndia.png
# http://www.ceilandia.df.gov.br/
# 5/6
# 14/15
# http://cnes.datasus.gov.br/Exibe_Ficha_Estabelecimento.asp?VCo_Unidade=5219752437627
# http://www.muchogusto.com.br/
# http://www.ceilandia.df.gov.br/
# SCRN 708/709 Bloco A
# SCRN 708/709 Bloco A
# SCRN 708/709 Bloco B
# SCRN 708/709 Bloco B
# SCRN 708/709 Bloco D
# SCRN 708/709 Bloco F
# SCRN 708/709 Bloco H
# SCRN 708/709 Bloco D
# SCRN 708/709 Bloco C
# SCRN 708/709 Bloco E
# SCRN 708/709 Bloco G
# SCRN 708/709 Bloco C
# SCRN 708/709 Bloco F
# SCRN 708/709 Bloco H
# SCRN 708/709 Bloco G
# SCRN 708/709 Bloco E
# SCRN 708/709 Bloco E
# http://www.hostel7.com.br/
# SCRN 708/709 Bloco A
# SCRN 708/709 Bloco B
# SCRN 708/709 Bloco F
# http://www.sabinonline.com.br/
# http://www.sabinonline.com.br
# Loja 08/09
# pt:Sudoeste/Octogonal
# Sudoeste / Octogonal
# 24/7
# EQNM 03/05 Área Especial
# Ponto Roncador / Chapada do Rodeador / Chapada Vendinha
# http://www.sicoob.com.br
# SCRN 708/709
# Setor Comercial Residencial Norte 708/709
# QS 5 Rua 800 LT 50/52
# LT 50/52
# http://www.viraventos.com.br/
# http://www.fepecs.edu.br/
# CO/UnB
# CLN 07 bloco C lotes 3/4 térreo
# http://www.hajimejapanesefood.com
# 24/7
# Churrascaria Floresta / Espaço
# CLS 409 Bloco B Loja 15/16
# CNB 8/CNB 9
# http://www.ipea.gov.br
# http://cradf.org.br
# http://www.rnp.br
# http://saborvital.com/
# CLN 07 bloco C lotes 1/2
# 3399-5129/3404-5892
# CLS 04 Conjunto C Lotes 3/4
# Marvin / Marietta
# http://portal.cfm.org.br/
# Brasília/DF
# 24/7
# http://www.unepxmildf.com.br/
# http://clinicaibed.com.br
# http://www.cycling.com.br
# CLS 310 Bloco C lojas 32/34
# http://www.sn2.com.br/
# http://www.bikesportbr.com.br
# http://www.biketechbrasilia.com.br
# http://www.superbike101.com.br
# CLSW 101 bloco C lojas 30/32
# http://www.unibike.com.br
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://www.girabike.com.br
# http://maisbikecompartilhada.com.br/
# http://www.e-vida.org.br
# http://www.konistore.com.br/
# http://www.popobrasil.com
# http://metododeroseasanorte.com.br
# http://www.restaurantexiquexique.com.br/
# http://ru.unb.br/
# Fundação Cultural Palmares/Minc
# http://www.crepeauchocolat.com.br
# http://realpapelaria.com.br
# http://www.popobrasil.com
# 24/7
# 24/7
# W5 Norte / SGAN 912
# http://islambrasilia.blogspot.com.br
# http://www.celc.org.br
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# Americanas / Blockbuster
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://www.subway.com.br
# http://donalenha.com.br/
# 24/7
# http://www.livrariamix.com
# http://www.cafeclandestino.com.br
# http://www.ilpandrino.com.br
# http://www.veterinariauberaba.com
# Cidade codificada com CEP por logradouros, a partir de 28/11/2014. Sistema de endereçamento: Bairro, quadra, lote.
# http://santoantoniododescoberto.go.gov.br/
# http://www.greens.com.br/
# http://www.caramellaconfeitaria.com.br/
# https://bsbmemo.com/
# http://objetoencontrado.com.br
# http://www.cafedanielbriand.com
# http://amoranatureza.com.br/
# http://www.bikeworlddf.com.br
# http://metododerosesudoeste.com.br
# http://maisbikecompartilhada.com.br/
# http://www.obistroescondido.com.br
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://www.tiogu.com
# http://culturadigital.br/labceus/2014/11/28/aguas-lindas-de-goias/#!/loc=-15.748671815354848,-48.281795382499695,17
# http://www.panetutti.com.br/
# 24/7
# http://www.bioon.com.br/
# http://www.ebserh.gov.br
# EQS 202/203
# http://maisbikecompartilhada.com.br/
# EQ 13/15 Bloco C
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://www.lapalma.com.br/
# http://genghiskhan.com.br
# 24/7
# 24/7
# http://www.ispn.org.br
# 24/7
# 24/7
# http://pastelariavicosa.com.br
# http://www.hajimejapanesefood.com
# 24/7
# http://smartfit.com.br
# 24/7
# 24/7
# +55 61 3381-6963 / 3568-4059 / 3381-8212
# http://www.sedest.df.gov.br/
# EQ 15/26 ÁREA COMUNAL 01
# http://www.aqua710.com.br
# http://www.inctinclusao.com.br/
# INCT Inclusão Instituto Central de Ciências - ICC Sul, lado A, Sala BSS 135/138 Campus Universitário Darcy Ribeiro - Caixa Postal 04561
# http://www.brazilianamericanburgers.com.br/
# http://www.grotemarkt.com.br/
# http://www.pinella.com.br
# 15/19
# CLN 408/409 BL C
# http://calango.club
# https://www.facebook.com/pages/Camberra-cervejas-especiais/1573150019575010
# http://www.facebook.com/AshramLounge/
# http://ticianawerner.com.br
# http://cafecristina.com.br
# http://www.greens.com.br
# http://cafebemcasado.com.br
# 24/7
# http://decurators.org/
# 24/7
# http://www.zeusnightclub.com/site/
# https://www.facebook.com/refresqueideias
# https://www.facebook.com/refresqueideias
# http://openwifi-br.net/
# http://www.dfxsuplementos.com/
# CLS 215/216
# http://www.artefoto.com.br/
# http://www.sabin.com.br
# http://maisfiltros.com.br/
# http://yoparticipo.oep.org.bo/
# http://windsorhoteis.com/hotel/windsor-brasilia/
# https://www.facebook.com/pg/gaiaemporio/
# Prefeitura Municipal de Padre Bernardo / GO.
# Prefeitura Municipal de Padre Bernardo / GO.
# 24/7
# 24/7
# http://pt.wikipedia.org/wiki/Torre_de_TV_de_Bras%C3%ADlia
# http://www.funai.gov.br/
# http://www.cultura.gov.br
# http://www.facebook.com/h2ecobsb
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# EQN 104/105
# http://maisbikecompartilhada.com.br/
# EQS 104/304
# http://maisbikecompartilhada.com.br/
# EQS 204/205
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# W2/EQN305/306
# http://maisbikecompartilhada.com.br/
# http://www.geja.blog.br/
# http://www.granciclismolazzaretti.com.br
# http://endossa.com/
# Espaço f/508 de Fotografia
# http://f508.com.br
# Quintal f/508
# http://f508.com.br/quintal/
# http://pizzariamarinelle.com.br/
# http://www.caixa.gov.br
# http://www.restaurantexiquexique.com.br
# http://popofightclub.com.br
# http://dalmoribeiro.com/
# W2 Sul / CRS 509
# 24/7
# S/N
# 24/7
# http://studiolorenaguerra.com.br
# http://www.softsystem.com.br/
# 24/7
# 24/7
# 24/7
# 24/7
# http://endossa.com/
# 24/7
# CLS 215/216
# http://playhotel.com.br/
# facebook.com/restaurantemanati
# http://www.marcelorocha.com/
# http://riliongraciebrasilia.com.br/site/
# CLNW 10/11 bloco D loja 04
# Lote 150/180
# http://planaltocopiadora.com.br
# http://www.rmater.org.br
# http://www.dlurdes.com.br/
# Rua 19 Sul Lotes 10/12
# http://www.afbrasilia.org.br/
# http://www.espacomultiplicidade.com.br
# http://www.rastreamentobsb.com.br
# 630/700
# http://leidybordados.com.br
# http://www.griffepneus.com.br
# http://www.youmove.com.br/
# CLN 408/409
# http://casadascamisetas.com.br/
# http://novatics.com.br/
# CLN 215/216
# 24/7
# Segunda Avenida Bloco 796/802
# http://www.duoorestaurante.com.br/
# CLN 207/208
# http://harmoniapisos.com.br/
# http://emporiocultural.net.br
# http://www.eadnainternet.com.br
# SGON Quadra 05, Lote 15/18. Asa norte
# http://www.mendesturbsb.com.br
# CLSW 302, Bloco C, Lojas 22/24/26/30, Sudoeste, Brasília
# W2 Sul / CRS 507
# 24/7
# 24/7
# http://espaco-cultural.webflow.io
# 24/7
# http://cantucci.com.br
# http://www.voiacafe.com.br
# http://www.construporto.com.br
# http://elefantecentrocultural.com
# http://www.mestre-cervejeiro.com/
# http://www.catedralortodoxa.com.br/paroquia-brasilia
# 602/603 Norte
# http://www.papricaburger.com/
# https://www.instagram.com/clubederemadakaluana/
# http://saborlight.com.br/
# Avenida das Castanheiras, Q. 104 Lotes 1310/1370, Edifício Real Splendor
# http://www.apub.com.br/
# http://www.lapalma.com.br/
# 24/7
# 24/7
# https://www.lucasexperience.com.br/
# https://www.manifestocoworking.com
# https://www.facebook.com/sultanbarbsb/
# https://www.jointheadshopsmoke.com/
# http://dolcefarnientedf.com.br/
# 24/7
# Qs309/307 Sul
# Seluz/Cesel Amparo a Criança
# Seluz/Cesel Amparo a Criança
# http://www.cafeeumchero.com.br
# 24/7
# 24/7
# http://www.thebraincoworking.com.br
# http://www.55lab.co
# http://saude.gov.br
# http://www.restaurantechinashow.com.br
# https://www.acaiartesanal.com.br/
# https://www.acaiartesanal.com.br/
# 2221/2231
# http://www.alub.com.br
# 4/6
# 4/6
# http://www.theblackbeef.com.br
# http://www.espaco365.com.br
# http://opencoworking.com.br/
# http://www.papomobile.com
# http://co-piloto.me
# http://cobrasilha.com.br
# https://www.thook.com.br
# http://enac.iscv.com.br/
# http://tempoecoarte.com.br
# http://gunga.com.br
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# 11L/29R
# SEPS EQ 714/914
# SEPS EQ 710/910
# SEPS EQ 708/908
# W2 Sul / CRS 506
# EQNP 24/28
# EQNP 24/28
# SEPS EQ 704/904
# CSB 9/10
# CSB 5/6
# SIA Trecho 14/16
# CLS 105/106
# EQRSW 2/3
# CLN 103/104
# CLS 404/405
# http://www.garveyparkhotel.com.br
# CLN 408/409
# CLN 412/413
# Correios 204/404 Norte
# SQN 403/404
# CLN 406/407
# CLN 410/411
# CLN 412/413
# CLN 113/114
# CLN 115/116
# http://www.brasiliashopping.com.br/
# http://www.gdf.df.gov.br/042/04299003.asp?ttCD_CHAVE=107233;Bing
# W2 Norte / CRN 502
# CLN 412/413
# CLN 402/403
# 24/7
# EQN 504/505
# 506/507 Norte
# 508/509 Norte
# http://www.extra.com.br/Atendimento/LocalizadorLojas.aspx
# CLN 314/315
# CLN 312/313
# CLN 310/311
# EQN 510/511
# EQN 510/511
# CLN 308/309
# CLN 306/307
# CLN 213/214
# CLN 109/110
# W2 Norte / SEPN 505
# W2 Norte / SEPN 507
# W2 Norte / SEPN 509
# W2 Norte / SEPN 511
# W2 Norte / SEPN 513
# W2 Norte / SEPN 515
# http://iesb.br
# http://www.golfebrasilia.com.br/
# CLS 402/403
# CLS 103/104
# CLS 312/313
# CLS 310/311
# CLS 109/110
# CLS 308/309
# CLS 308/309
# CLS 302/303
# CLS 306/307
# W2 Sul / CRS 504
# CLS 107/108
# W2 Sul / CRS 514
# W2 Sul / CRS 512
# W2 Sul / CRS 510
# W2 Sul / CRS 508
# W2 Sul / CRS 502
# CLS 410/411
# SEPS EQ 706/906
# SEPS EQ 712/912
# http://www.patiobrasil.com.br
# CRN 702/703
# CRN 704/705
# Ministério do Desenvolvimento Agrário / Esporte / SEPPIR/ PR / Cidades
# Ministério da Cultura / Meio Ambiente
# Ministério do Planejamento, Orçamento e Gestão / Desenvolvimento Social e Combate à Fome
# Ministério da Agricultura, Pecuária e Abastecimento / Pesca e da Aquicultura
# Ministério da Ciência, Tecnologia e Inovação / Integração Nacional
# Ministério da Previdência Social / Trabalho e Emprego
# Ministério de Minas e Energia / Turismo
# Ministério das Comunicações / Transportes
# http://www.caminheirosbsb.com.br
# EQNO 1/3
# 11R/29L
# http://pt.wikipedia.org/wiki/Pra%C3%A7a_do_Compromisso
# EQL 6/8
# Rodovia BR-040/BR-050
# PMU2 / CIFMC - Predio Multiuso 2
# SG10 - CEPLAN / Núcleo de Vivência
# http://www.brasiliapalace.com.br
# http://www.pnse.com.br/
# CLN 107/108
# http://www.sedest.df.gov.br
# http://www.saude.df.gov.br
# http://www.df.gov.br/index.php/2016/02/22/memorial-jk/
# SGAS Quadra 914 Conj. A Lts 63/64
# http://www.esaf.fazenda.gov.br/
# SMLN MI3 Conjuntos 4 / 5
# SMLN MI3 Conjuntos 1 / 2
# SMDB Conjuntos 30 / 31
# http://www.prg.df.gov.br
# SOF SUL Quadra 3/4
# CLS 215/216
# SCRN 712/713
# SCRN 712/713
# CLN 404/405
# CLN 211/212
# CLN 111/112
# CLN 304/305
# http://www.emack.com.br/bsb/geral/localizacao.php
# CRN 704/705
# CLS 203/204
# W5 Norte / SGAN 916
# CSB 3/4
# CSB 4/5
# CSB 1/2
# CSB 2/3
# CSB 7/8
# CNB 11/CNB 12
# C2/C3
# C1/C2
# SMDB Conjuntos 26 / 27
# http://www.cmb.ensino.eb.br
# SGO Quadra 2 / 3
# SOF SUL Quadra 9/10
# Anexo do Ministério da Previdencia Social / Trabalho
# SHC/S Qd. 102/103
# CLN 105/106
# EQRSW 4/5
# SIG - Quadra 2/4
# http://culturabancodobrasil.com.br/portal/distrito-federal/
# Bloco B / C
# EQS 212/213
# Bloco A / E
# Bloco G / H
# Bloco A / B
# Bloco D / I
# http://www.11gaaae.eb.mil.br
# Estrada do Parque de Abastecimento e Contorno - S/Nr
# http://www.senado.gov.br/
# Bloco I/J
# Bloco B / C
# Bloco J / K
# http://portal.in.gov.br
# EQL 2/4
# EQNP 10/14
# EQNP 10/14
# EQNP 14/18
# EQNP 14/18
# Via 6/7
# EQNP 11/7
# EQNN 3/5
# CLS 400/401
# EQNN 3/5
# EQNN 1/3
# EQNN 1/3
# AGETOP (http://www.agetop.go.gov.br/post/Vereador /139056/rodovias-de-goias)
# AGETOP (http://www.agetop.go.gov.br/post/Ver/139056/rodovias-de-goias)
# EQNM 24/26
# EQNP 19/15
# EQNP 19/15
# EQNN 4/6
# EQNN 4/6
# EQNn /8
# eqnm 18/20
# EQno 4/6
# EQNO 2/4
# EQNO 2/4
# EQNO 2/4
# EQNM 8/10
# EQNM 8/10
# EQno 4/6
# EQno 4/6
# EQNM 6/8
# EQNM 6/8
# EQNM 4/6
# EQNM 4/6
# EQNM 2/4
# EQNM 2/4
# EQNN 2/4
# EQNM 1/3
# EQNM 1/3
# EQNM 24/26
# EQNM 24/26
# EQNM 3/5
# EQNM 3/5
# EQNn /8
# EQNM 5/7
# EQNM 5/7
# EQNM 7/9
# EQNM 7/9
# EQNM 23/25
# EQNM 23/25
# EQNM 21/23
# EQNM 21/23
# EQNM 19/21
# EQNM 19/21
# EQNM 17/19
# EQNM 17/19
# EQNN 7/9
# EQNN 7/9
# EQNN 18/20
# EQNN 24/26
# EQNN 24/26
# EQNN 22/24
# EQNN 22/24
# EQNN 20/22
# EQNN 17/19
# EQNN 8/10
# EQNN 20/22
# EQNN 8/10
# EQNN 18/20
# EQNN 17/19
# EQNN 19/21
# EQNN 19/21
# EQNM 20/22
# EQNM 22/24
# EQNM 22/24
# EQNM 20/22
# EQNM 18/20
# EQNM 18/20
# EQNP 17/13
# EQNP 17/13
# EQNP 13/9
# EQNP 11/15
# EQNP 13/9
# EQNP 11/15
# EQNN 21/23
# EQNN 21/23
# EQNP 16/20
# EQNP 16/20
# EQNP 12/16
# EQNP 12/16
# http://www.cbm.df.gov.br
# EQNP 23/25
# EQNP 23/25
# EQNP 30/34
# EQNP 30/34
# EQNP 26/30
# EQNP 26/30
# EQNP 22/26
# EQNP 6/10
# EQNP 8/12
# EQNP 32/36
# Setor Colônia Agrícola Samambaia - Chacara 1/2
# http://www.leonardodavincidf.com.br/
# http://www.fhb.df.gov.br/003/00318002.asp?ttCD_CHAVE=6626
# http://www.phu.org.br/
# http://www.embrapa.gov.br
# Centro de Sensoriamento Remoto (CSR) / PrevFogo / Serviço Florestal Brasileiro (SFB)
# http://www.santalucia.com.br/
# SCRN 706/707 Bloco E
# SCRN 706/707 Bloco A
# https://www.mercadoviagens.com/
# https://www.mercadoviagens.com/
# Blocos J / I
# SMPW Quadra 17 - Conjunto 9/10
# Bloco A / B
# Bloco H / I
# Bloco D / E
# Bloco I / J
# Bloco I/J
# Bloco H / K
# Bloco B / F
# Bloco J / K
# Bloco C / F
# Bloco J / K
# Bloco A / B
# Bloco J / K
# EQS 106/107
# Bloco E / F
# Bloco I / J
# Bloco A / E
# Bloco A / B
# Bloco J / K
# Bloco C / G
# Bloco J / K
# Bloco A / B
# Bloco J / K
# Bloco E / F
# Bloco B / C
# Bloco J / K
# http://www.terrapuradf.org.br/
# Bloco D / E
# Anexo do Ministério da Integração Nacional / Fazenda
# http://www.fnde.gov.br
# Bloco H / I
# Blocos G / H
# Blocos E / A
# Blocos E / A
# Blocos J / K
# Blocos E / A
# Blocos B / C
# Bloco A / E
# Blocos B / C
# Bloco C / D
# Blocos G / H
# Bloco B / C
# Bloco B / C
# Blocos I / J
# Blocos K / J
# Bloco A / B
# Bloco A / B
# Bloco J / K
# Bloco I / J
# Bloco A / B
# Regional de Ensino do Plano Piloto/Cruzeiro
# Regional de Ensino do Plano Piloto/Cruzeiro
# Regional de Ensino do Plano Piloto/Cruzeiro
# Bloco C/D
# Bloco A / B
# Regional de Ensino do Plano Piloto/Cruzeiro
# http://www.cnj.jus.br
# W2 Norte / SEPN 514 Lote 7 bloco b
# Bloco G / H
# Bloco A / B
# Bloco J / I
# Bloco A / B
# Bloco J / K
# Bloco J / L
# Bloco A / B
# Bloco A / C
# Bloco F / H
# Bloco A / B
# Bloco F / G
# Bloco A / E
# Bloco G / I
# Bloco D / F
# Bloco C / E
# EQNP 30/32
# EQNP 32/36
# EQNP 28/32
# EQNP 28/32
# Bloco K / J
# Bloco C / H
# http://www.cade.gov.br
# Bloco A / B
# http://brasiliahd.com.br
# W2 Norte / SEPN 510
# http://www.libertymall.com.br/
# SEP Sul 715/915 Conjunto A
# http://www.faculdadeprojecao.edu.br
# http://www.minasbrasilia.com.br/
# http://www.upis.br/
# SEPS EQ 715/915
# http://www.tse.jus.br
# http://www.ambafrance-br.org/
# http://www.eda.admin.ch/brasilia
# http://www.embperu.org.br/
# http://thesunresort.com.br/
# http://www.hplus.com.br/hoteis/life-resort-hplus-long-stay/
# Associação do Pessoal da Caixa Econômica Federal do DF (APCEF/DF)
# APCEF/DF
# CNA/SENAR
# http://serpro.gov.br
# http://www.ccbnet.org.br/
# http://www.assefe.com.br
# COPM/DF
# http://redesagrado.com/corjesu/
# http://www.iesb.br
# http://casadocandango.org.br
# http://www.iabdf.org.br/
# http://www.csrdf.com.br
# http://www.casadovovo.org
# http://vivendoeaprendendo.org.br
# http://www.ifb.edu.br
# Regional de Ensino do Plano Piloto/Cruzeiro
# SEPS 712/912
# http://iesplan.br
# SHVP Rua 12 - Chácara 151/1
# Avenida Central Blocos 71 / 91
# Avenida Central Blocos 31 / 51
# Avenida Central Blocos 151 / 171
# Avenida Central Blocos 111 / 131
# Avenida Central 191 / 211
# NB4 / Blocos 1200 e 1220
# SH Arniqueiras / Colônia Agrícola Vereda Grande, Chácara 53
# Chacara 83/1
# Chacara 70/1
# CAVC Chácara 1/2
# CAVC Chácara 1/2
# CAVC Chácara 12/1
# CAVC Chácara 26/27
# CAVC Chácara 21/21A
# CAVC Chácara 26/27
# CSG 2/4
# DER/DF - 3ºDistrito Rodoviário
# Quadra QR 606 Conjunto 06/07
# Quadra QR 606 Conjunto 14/07
# Quadra QR 606 Conjunto 04/05
# Quadra QR 606 Conjunto 13/12
# Quadra QR 606 Conjunto 03/04
# Quadra QR 606 Conjunto 12/11
# Quadra QR 606 Conjunto 14/13
# Quadra QR 606 Conjunto 11/10
# Anexo do Ministério dos Transportes / Comunicações
# CRN 714/715
# CRN 714/715
# SCRN 708/709 Bloco A
# SCRN 708/709 Bloco E
# SCRN 706/707 Bloco A
# SCRN 706/707 Bloco E
# http://www.uniceub.br/
# SEPN 707/907
# EQL 11/13
# EPTG EQ 1/2
# EPTG EQ 2/3
# indoor/outdoor
# SHVP - Chácara 26/1
# SHVP - Chácara 26/1
# SHVP - Chácara 26/1
# CLS 111/112
# http://jcbrasilia.com.br
# Sle EQ 44/45
# SHVP Rua 12 - Chácara 144/1
# SHVP Rua 10 - Chácara 154/1
# SHVP Rua 12 - Chácara 152/1
# SHVP Rua 12 - Chácara 149/1
# SHVP Rua 12 - Chácara 154/3
# SHVP Rua 12 - Chácara 140/1
# SHVP Rua 12 - Chácara 145/1
# SHVP Rua 12 - Chácara 143/1
# SHVP Rua 12 - Chácara 146/1
# SHVP Rua 12 - Chácara 142/1
# SHVP Rua 12 - Chácara 138/1
# SHVP Rua 12 - Chácara 147/1
# SHVP - Rua 10 - Chácara 155/1
# SHVP - Rua 8 - Chacara 327/1
# Setor Colônia Agrícola Samambaia - Chacara 68/1
# Setor Colônia Agrícola Samambaia - Chacara 148/1
# SHVP - Rua 4 - Chácara 192/1
# SHVP - Rua 4 - Chácara 192/1
# SHVP - Rua 7 - Chácara 34/1
# SHVP - Rua 4 - Chácara 191/1a
# SHVP - Rua 5 - Chácara 101/1
# SHVP - Rua 10 - Chácara 323/1
# Qr 210 / 310 Conjunto B
# Qr 209 / 309 Conjunto N
# Qr 209 / 309 Conjunto N
# 05/23
# CL 202 / CL 203
# Rua 25/A
# S/N
# S/N
# http://www.tst.jus.br/
# CNB 3/CNB 4
# Avenida Comercial Sul / QSA 1
# http://www.jardimbotanico.df.gov.br/
# CLS 414/CLS 415
# CLS 412/413
# CLS 213/214
# CLS 408/409
# http://estadionacionaldebrasilia.com.br/
# Laboratório de Estudos Geodinâmicos e Ambientais (LEGA) / Laboratório de Geocronologia
# EQL 11/13
# http://www.itamaraty.gov.br/
# https://revistamoarabrasilia.wordpress.com/a-escola-moara/
# 24/7
# 24/7
# Sudoeste / Octogonal
# Lote 01/11B
# SIA Trecho 1/2
# EQNO 1/3
# EQNO 9/11
# EQNO 2/4
# EQNO 4/6
# EQNO 3/5
# EQNO 11/13
# EQNO 13/15
# EQNO 5/7
# http://www.bigbox.com.br/
# http://www.atacadao.com.br
# Regional de Ensino do Plano Piloto/Cruzeiro
# http://www.boulevardbrasilia.com.br
# W5 Norte / SGAN 906
# Regional de Ensino do Plano Piloto/Cruzeiro
# http://www.jardimbotanicoshopping.com.br/
# LOTES 24/25
# EQ 15/16
# EQNO 5/7
# EQno 4/6
# EQno 4/6
# EQno 4/6
# http://www.taguatingashopping.com.br
# CCSW 6 bloco C/D
# EQNP 24/28
# EQNP 22/20
# EQNP 22/26
# EQNP 8/12
# EQNP 26/30
# EQNP 26/30
# EQNP 12/16
# EQNP 12/16
# EQNP 10/14
# EQNP 10/14
# EQNP 14/18
# SCES Trecho 1 Conjunto 3 Lote 5/6
# SCES Trecho 1 Conjunto 7 Lote 1/4
# EQNP 8/12
# EQNP 6/10
# EQNP 6/10
# EQNN 4/6
# QNP 5/1
# QNP 5/1
# EQNP 9/5
# EQNP 9/5
# EQNP 9/5
# EQNP 9/5
# EQNP 9/5
# EQNP 17/13
# EQNP 17/13
# EQNP 17/13
# EQNP 17/13
# EQNP 17/13
# EQNO 10/12
# EQNM 5/7
# EQNN 5/7
# EQNM 5/7
# eqnn 3/5
# EQNN 1/3
# EQNN 1/3
# eqnm 18/20
# EQNM 4/6
# QNM 20/22
# EQNM 22/24
# EQNM 6/8
# EQNO 9/11
# EQNO 2/4
# EQNO 2/4
# EQNP 11/15
# EQNP 11/15
# QNM 20/22
# EQNN 5/7
# EQSW 301/302
# SCS Quadra 8/9
# Área Especial QE 15/16
# EQNP 32/36
# EQNP 30/32
# http://www.estanciagaucha.com.br
# 24/7
# EQ 32/34
# EQSW 303/304
# http://www.etc.se.df.gov.br/
# MR 6 / MR 5
# MR 2 / MR 1
# MR 4/ MR 3
# MR 5 / MR 4
# MR 3 / MR 2
# 24/7
# http://www.asceb.com.br/
# SCRN 708/709 Bloco A
# SCRN 708/709 Bloco H
# SCRN 708/709 Bloco F
# SCRN 708/709 Bloco B
# SCRN 708/709 Bloco G
# SCRN 708/709 Bloco C
# SCRN 708/709 Bloco D
# SCRN 708/709 Bloco E
# http://www.tokyorestaurante.com.br
# http://www.uniplandf.edu.br
# http://www.institutoprocessus.com.br
# Sudoeste / Octogonal
# Sudoeste / Octogonal
# Sudoeste / Octogonal
# Sudoeste / Octogonal
# http://www.inmet.gov.br
# SCS Quadra 7/8
# QI 27 Lote 3/5
# QI 27 Lote 3/5
# QI 27 Lote 3/5
# Lotes 165/195
# EQNP 32/36
# EQNP 16/20
# SHVP Rua 12 - Chácara 139/1
# SHVP Rua 12 - Chácara 148/1
# SHVP Rua 12 - Chácara 141/1
# SHVP Rua 12 - Chácara 154/2
# SHVP Rua 12 - Chácara 153/1
# SHVP Rua 12 - Chácara 137/1
# SHVP - Rua 10 - Chácara 325/326
# SHVP - Rua 10 - Chácara 155/1
# SHVP - Rua 2b - Chácara 192/3
# QUADRA 8 CONJUNTO A / QUADRA 6 CONJUNTO D
# Lotes 190/250
# CLNW 10/11 Bloco E - Edifício Neo E
# CLNW 10/11
# CLNW 10/11 Bloco D - Edifício Neo D
# CLNW 10/11
# CLNW 10/11 Bloco C - Edifício Neo C
# CLNW 10/11
# CLNW 10/11 Bloco B
# CLNW 10/11
# CLNW 10/11 Bloco A
# CLNW 10/11
# http://jkshoppingdf.com.br
# Quadra de Volei/Futevolei
# 24/7
# http://www.clubedochoro.com.br/
# SAIN Q. 04 lote s/n
# CNB 10/CNB 11
# EQSW 103/104
# EQSW 304/504
# EQRSW 5/6
# EQRSW 3/4
# EQRSW 1/2
# EQRSW 6/7
# EQRSW 7/8
# http://serpro.gov.br
# http://www.unieuro.edu.br/
# http://www.ucb.br
# SOF SUL Quadra 7/8
# CLN 207/208
# EQL 6/8
# http://www.detran.df.gov.br/
# http://www.borgeslandeiro.com.br/
# CNB 4/CNB 5
# CNB 9/CNB 10
# CNB 5/CNB 6
# CNB 7/CNB 8
# CNB 1/CNB 2
# SCS Quadra 2/3
# CNB 8/CNB 9
# SCRN 708/709 Bloco B
# SCRN 708/709 Bloco C
# SCRN 708/709 Bloco D
# SCRN 708/709 Bloco G
# SCRN 708/709 Bloco G
# SCRN 708/709 Bloco F
# Terracap: http://www.terracap.df.gov.br/terracapweb/edital/croquis_112013/59a63.jpg
# http://www.terracap.df.gov.br/terracapweb/edital/croquis_112013/59a63.jpg
# QNG 46 A/E
# Clínica da Família 104/105
# QSD 09/11
# http://www.acibdf.com.br
# http://www.villagealvorada1.com.br/
# DEC 88.940 de 07/11/1983
# DEC/SN 13/12/2002
# http://www.saobernardodf.com.br
# http://cinedrivein.com/
# http://www.adbraz.com.br
# Correios 208/408 Sul
# Sudoeste / Octogonal
# SCRN 706/707
# Setor Comercial Residencial Norte 706/707
# SCRN 706/707 Bloco B
# SCRN 706/707 Bloco C
# SCRN 706/707 Bloco D
# SCRN 706/707 Bloco F
# SCRN 706/707 Bloco G
# SCRN 706/707 Bloco H
# SCRN 706/707 Bloco B
# SCRN 706/707 Bloco C
# SCRN 706/707 Bloco D
# SCRN 706/707 Bloco F
# SCRN 706/707 Bloco G
# SCRN 706/707 Bloco H
# Clube do Flamengo / Tiradentes
# CLN 203/204
# CLN 209/210
# CLN 205/206
# CLS 201/202
# CLS 205/206
# CLS 207/208
# CLS 209/210
# CLS 211/212
# CLS 113/114
# CLS 115/116
# CLN 201/202
# CLN 215/216
# W5 Norte / SGAN 901
# EQN 412/413
# CLN 302/303
# http://www.iphan.gov.br/
# 713/913
# CLS 406/407
# CLS 408/409
# W2 Sul / CRS 516
# Area Especial 4, Lotes G/H
# CNB 6/CNB 7
# SCRN 710/711
# QSE 12/14
# CNB 2/CNB 3
# http://www2.camara.leg.br/a-camara/estruturaadm/cefor
# SAUN Quadra 2 / 3
# SOF SUL Quadra 12/13
# SEPS EQ 702/902
# SEPS EQ 703/903
# SEPS EQ 705/905
# SEPS EQ 707/907
# SEPS EQ 709/909
# SEPS EQ 711/911
# SEPS EQ 713/913
# W2 Sul / CRS 503
# W2 Sul / CRS 505
# W2 Sul / CRS 507
# W2 Sul / CRS 509
# W2 Sul / CRS 511
# W2 Sul / CRS 513
# W2 Sul / CRS 515
# W2 Norte / SEPN 503
# W2 Norte / SEPN 506
# W2 Norte / SEPN 508
# W2 Norte / SEPN 510
# W2 Norte / SEPN 512
# W2 Norte / SEPN 514
# W2 Norte / SEPN 516
# CRN 702/703
# SCRN 710/711
# W2 Norte / SEPN 504
# W5 Norte / SGAN 902
# W5 Norte / SGAN 903
# W5 Norte / SGAN 904
# W5 Norte / SGAN 905
# W5 Norte / SGAN 907
# W5 Norte / SGAN 908
# W5 Norte / SGAN 909
# W5 Norte / SGAN 910
# W5 Norte / SGAN 911
# W5 Norte / SGAN 912
# W5 Norte / SGAN 913
# W5 Norte / SGAN 914
# W5 Norte / SGAN 915
# 3399-7186/5440
# QS 16 Área Especial 14/15
# http://www.1rcg.eb.mil.br/
# http://fga.unb.br/
# Rua 19 Norte Lotes 1/3
# http://www.inep.gov.br
# Avenida Comercial / QNE 6
# EQNN 8/10
# EQNN 6/8
# EQNN 4/6
# EQNM 9/7
# capturado com gps dia 20/04/2014 falta mais trilhas para completar o traçado do novo valão do aeroporto
# (p/ terceira idade)
# http://www.smtokio.com.br/
# W5 Norte / SGAN 901
# http://ferrarikart.com/
# http://recantodocamarao.com.br/site/o-restaurante/
# http://www.ctgjcb.com.br
# EQNM 8/10
# EQNM 6/8
# EQNM 4/6
# EQNM 2/4
# EQNN 1/3
# EQNN 3/5
# EQNN 5/7
# EQNN 7/9
# EQNN 21/23
# EQNN 23/25
# EQNP 17/13
# EQNP 13/9
# EQNP 9/13
# EQNP 9/5
# EQNP 5/9
# EQNP 5/1
# EQNP 1/5
# http://www.abrace.com.br/
# Bing/IBGE
# https://www.iflyworld.com/brasilia/
# Rua 18 Sul Lotes 9/11
# http://condominiorivoli.blogspot.com.br/
# capturado com gps dia 20/04/2014 falta mais trilhas para completar o traçado do novo valão do aeroporto
# EQNM 1/3
# EQNM 3/5
# EQNM 5/7
# EQNM 7/9
# EQNN 2/4
# EQNP 12/16
# EQNN 2/4
# QI 17 / QI 18
# EQNP 22/20
# EQNP 28/32
# Quadra QR 606 Conjunto 12/05
# Quadra QR 606 Conjunto 10/03
# Quadra QR 606 Conjunto 05/06
# http://www.dnit.gov.br/mapas-multimodais/shapefiles
# http://fga.unb.br/
# http://fga.unb.br/
# http://fga.unb.br/
# SKY BANDALARGA / SKY HDTV REGIONAL 4
# 85/95
# http://cdt.unb.br/
# Anexo do CEFTRU / INFRALAB
# PDG / Brookfield
# http://capelavnavi.zip.net/
# Santo Antônio do Descoberto/GO
# CLS 314/315
# 24/7
# Quadra A / Chácara 73
# Quadras D / E
# Quadras F / G
# Quadras A / B
# Quadra E / Área Especial
# Quadras I / J
# Quadras C / D
# Quadras B / C
# http://www.cejb2.com.br/
# https://pt-br.facebook.com/pages/Academia-Sport-Point/155039214556072
# Conjunto C / D
# Conjunto D / E
# Conjunto B / C
# Conjunto A / B
# http://www.mansoescalifornia.com.br/
# CSB 6/7
# CSB 8/9
# http://www.cnpq.br/
# 61) 3432-2108 / 3981-1149
# 17/21
# (61) 3642 1483 / 3981 1150
# http://www.templodadeusa.com.br/
# http://www.eplanetainfantil.com
# Chácara 119 / 125
# http://www.unb.br
# Instituto de Ciência Política / Instituto de Relações Internacionais (IPOL/IREL)
# IPOL/IREL
# Departamento de Ciência da Computação / Departamento de Estatística (CIC/EST)
# CIC/EST
# 11/13
# EQ 13/15
# W5 Norte / SGAN 916
# 6/7
# QSA 24/25
# QSA 03/05
# AE 01/02
# http://escoladabiblia.org.br/
# S/N
# SIA Trecho 14/16
# http://www.ubtescalada.com.br
# https://pt.foursquare.com/v/audit%C3%B3rio-petr%C3%B4nio-portela/4e0c94568877c535e46f26a7
# EST BSB/PADRE BERNARDO - DF-180 - KM-25
# http://www.ibama.gov.br
# http://www.hospitaldaher.com.br
# http://www.katanka.com.br/
# CLS 304/305
# http://www.ucb.br/
# Cond. Chácaras Itaipú, Ch. 81/82
# Condomínio Chácaras Itaipú, Ch. 81/82
# Cond. Chácaras Itaipú, Ch. 20/23
# Cond. Chácaras Itaipú, Ch. 20/23
# S/N
# AGETOP (http://www.agetop.go.gov.br/post/Ver/139056/rodovias-de-goias)
# http://crossfitlagonorte.com/
# Rodovia BR-040/BR-050
# http://www.selfstok.com.br
# http://portal.imprensanacional.gov.br/museu/
# SHVP - Rua 10 - Chácara 1155/1
# CRN 702/703
# Rua 19 Norte Lotes 6/8
# http://lyceefrancaisbrasilia.com/
# http://www.mozambique.org.br/
# Regional de Ensino do Plano Piloto/Cruzeiro
# Regional de Ensino do Plano Piloto/Cruzeiro
# Regional de Ensino do Plano Piloto/Cruzeiro
# Regional de Ensino do Plano Piloto/Cruzeiro
# Regional de Ensino do Plano Piloto/Cruzeiro
# Regional de Ensino do Plano Piloto/Cruzeiro
# Regional de Ensino do Plano Piloto/Cruzeiro
# Regional de Ensino do Plano Piloto/Cruzeiro
# http://www.safa.com.br
# SGAN 906 - Módulo C / D
# http://metodista906.org.br/
# CLS 404/405
# SMDB Conjuntos 12 / 13
# dirt/sand
# 24/7
# https://www.grupocoqueiro.com.br
# Regional de Ensino do Plano Piloto/Cruzeiro
# CLS 400/401
# Avenida Samdu Sul / QSD 26
# Avenida Samdu Sul / QSD 18
# Avenida Samdu Sul/ QSD 1
# Avenida Samdu Sul / QSD 13
# Avenida Comercial Sul / QSA 12
# Avenida Comercial Sul / QSA 11
# Avenida Comercial Sul / QSA 2
# EQNP 14/18
# 613/614 Sul
# EQN 108/109
# Praça/Parque Qs 14
# http://indianembassy.org.br
# Parque 104/105
# Campinho 104/105
# dirt/sand
# religion was Católica_Ortodoxa -- couldn't find it in listed denominations - https://wiki.openstreetmap.org/wiki/Key:denomination
# http://www.institutoriobranco.mre.gov.br
# http://www.ifb.edu.br/taguatinga/
# Comércio da 209/210
# Comercial da 410/411
# http://vivendasbelavista.com.br/vivendas2/index.php
# Parque EQS 110/111
# Sle EQ 44/45
# http://www.salacias.com.br
# SMDB Conjuntos 28 / 28B
# http://upload.wikimedia.org/wikipedia/commons/0/05/Flag_of_Brazil.svg
# https://upload.wikimedia.org/wikipedia/commons/f/f4/Bandeira_de_Minas_Gerais.svg
# America/Sao_Paulo
# http://www.mg.gov.br/
# https://upload.wikimedia.org/wikipedia/commons/0/0e/Bandeira_de_Goi%C3%A1s.svg
# http://www.goias.gov.br/
# America/Sao_Paulo
# https://upload.wikimedia.org/wikipedia/commons/3/3c/Bandeira_do_Distrito_Federal_%28Brasil%29.svg
# http://www.df.gov.br/
# America/Sao_Paulo
# 312 - Setor O/ Rodoviária do Plano Piloto (via Estrutural)
# 382 - Setor O/Rodoviária do Plano Piloto (via Leste/Estrutural)
# 104 - Rodoviária do Plano Piloto/Palácio da Alvorada
# 140 - Rodoviária do Plano Piloto/Avenida das Nações Norte
# 107 - Rodoviária do Plano Piloto/W3-L2 Sul (Esplanada)
# 114 - Rodoviária do Plano Piloto/L2-W3 Sul
# 115.1 - Rodoviária do Plano Piloto/L2 - W3 Norte
# http://upload.wikimedia.org/wikipedia/commons/3/3c/Bandeira_do_Distrito_Federal_%28Brasil%29.svg
# http://www.brasilia.df.gov.br/
# 394 - Samambaia Sul/Rodoviária Plano
# http://upload.wikimedia.org/wikipedia/commons/0/08/Bandeira_de_Ceil%C3%A2ndia.png
# http://www.ceilandia.df.gov.br/
# Sudoeste / Octogonal
# pt:Sudoeste/Octogonal
# http://upload.wikimedia.org/wikipedia/commons/d/dc/Bandeira_de_Taguatinga_%28DF%29.svg
# http://www.taguatinga.df.gov.br/
# SCRN 708/709
# Setor Comercial Residencial Norte 708/709
# LEI 9.262 de 12/01/1996
# Área de Relevante Interesse Ecológico Capetinga/Taquara
# DEC 91.303 de 03/06/1985
# DEC/SN 10/06/1999
# LEI 11.285 de 08/03/2006
# DEC/SN 10/01/2002
# 0.169 - Cruzeiro/W3 Norte (Buriti-Avenida Comercial Sudoeste)
# Cruzeiro/W3 Norte (Buriti-Avenida Comercial Sudoeste)
# 116.1 - Circular Rodoviária do Plano Piloto/W3-L2 Norte/Esplanada
# 0.006 - Cruzeiro/Octogonal/Sudoeste/W3 Sul
# 0.006 - Cruzeiro/Octogonal/Sudoeste/W3 Sul
# 0.006 - Cruzeiro/Octogonal/Sudoeste/W3 Sul
# 0.006 - Cruzeiro/Octogonal/Sudoeste/W3 Sul
# Cruzeiro/Octogonal/Sudoeste/W3 Sul
# 0.165 - Sudoeste/Esplanada(Terraço Shopping-Buriti-HFA
# Sudoeste/Esplanada(Terraço Shopping-Buriti-HFA
# Linha 0.113 - Aeroporto/Eixo L/Esplanada/Setor Hoteleiro Norte-Sul/Centro de Convenções /Eixo W/Aeroporto
# Aeroporto/Eixo L/Esplanada/Setor Hoteleiro Norte-Sul/Centro de Convenções /Eixo W/Aeroporto
# http://www.tjdft.jus.br/
# http://www.cejbonline.com.br/
# 0.168 - Cruzeiro / Sudoeste / L2 Norte (UnB)
# 0.024 - Cruzeiro / Sudoeste / Esplanada (CNB)
# 183.2 - CIRCULAR - São Sebastião (res. bosque)/ Vila do Boa/ Condomínios (ESAF)
# http://www.terracoshopping.com.br/
# http://www.mbrengenharia.com.br/site/executive-office-tower/
# http://tishmanspeyer.com.br/comercial/green-towers
# .  ---------------------------------------------
# http://upload.wikimedia.org/wikipedia/commons/3/3c/Bandeira_do_Distrito_Federal_%28Brasil%29.svg
# http://www.brasilia.df.gov.br/
# Potlatch 0.10
# http://www.formosa.go.gov.br
# http://upload.wikimedia.org/wikipedia/commons/d/dc/Bandeira_de_Taguatinga_%28DF%29.svg
# http://www.taguatinga.df.gov.br/
# http://novageracao.academiaweb.com.br
# http://www.novositedogiraffas.com
# http://www.supercei.com.br
# ourairports.com
# ourairports.com
# ourairports.com
# ourairports.com
# ourairports.com
# ourairports.com
# ourairports.com
# ourairports.com
# ourairports.com
# ourairports.com
# ourairports.com
# ourairports.com
# ourairports.com
# ourairports.com
# ourairports.com
# caoguiadf@gmail.com
# Garagem do Ed. Sede do TCU
# 1063.0
# 1065.0
# 1049.0
# Melhor sorveteria de Brasilia. Best ice cream in Brasilia.
# Para usar o vestiário é preciso apresentar um documento com foto.
# http://www.popobrasil.com
# http://www.correios.com.br
# http://www.pisttache.com.br
# http://www.tuttisapori.com.br
# http://www.tokyorestaurante.com.br
# http://www.mansoori.com.br/portugues/localizacao.cfm
# http://www.mansoori.com.br/portugues/localizacao.cfm
# 71.961-540
# http://www.icesp.br/
# www.sigma.g12.br
# http://www.faculdadedarwin.com
# http://www.facitec.br/
# http://www.anhanguera.com/graduacao/localidades/brasilia_jk.php
# http://cinecultura.com.br/
# St. Paul Plaza Hotel
# http://www.hotelstpaul.com.br
# contato@itaucinemas.com.br
# http://itaucinemas.com.br
# http://www.companhiadaterra.com/
# http://www.ciadaterra.com
# http://www.drograriarosario.com.br
# http://www.drograriarosario.com.br
# 9a. Delegacia de Policia Civil
# http://bsb.aero/
# Adm. Regional do Riacho Fundo II
# http://www.giraffas.com.br/
# http://www.americanas.com
# http://upload.wikimedia.org/wikipedia/commons/0/08/Bandeira_de_Ceil%C3%A2ndia.png
# http://www.ceilandia.df.gov.br/
# http://cnes.datasus.gov.br/Exibe_Ficha_Estabelecimento.asp?VCo_Unidade=5219752437627
# Escola Municipal Dom Agostinho S. Januszewicz
# http://www.muchogusto.com.br/
# http://www.ceilandia.df.gov.br/
# info@hostel7.com.br
# http://www.hostel7.com.br/
# O Laboratório Sabin é o maior da região Centro-Oeste, com unidades no Distrito Federal e nos estados de Goiás, Bahia, Minas Gerais, Amazonas, Tocantins e Pará.
# http://www.sabinonline.com.br/
# http://www.sabinonline.com.br
# Improvisado, as bicicletas ficam presas em um corrimão perto da entrada do complexo. Existem guardas na proximidade, mas a segurança não é garantida.
# Para usar o vestiário é preciso apresentar um documento com foto.
# http://www.sicoob.com.br
# Dr. Colchão
# Sob a guarda do povo brasileiro, nesta Praça dos Três Poderes, a Bandeira sempre no alto - visão permanente da Pátria.
# http://www.viraventos.com.br/
# http://www.fepecs.edu.br/
# http://www.hajimejapanesefood.com
# entraecome@gmail.com
# http://www.ipea.gov.br
# http://cradf.org.br
# http://www.rnp.br
# http://saborvital.com/
# www.santander.com.br
# http://portal.cfm.org.br/
# Aqui você encontra os melhores rastreadores do mercado. Solução de rastreamento e proteção para seu carro e sua moto, com aplicações práticas no dia-a-dia. Simples e econômico, nosso rastreador permite a localização e bloqueio em qualquer lugar do Brasil
# http://www.unepxmildf.com.br/
# A Justiça é o nome de uma escultura localizada em frente ao prédio do Supremo Tribunal Federal, em Brasília. Foi feita em 1961 pelo artista plástico mineiro Alfredo Ceschiatti, em um bloco monolítico de granito de Petrópolis, medindo 3,3 metros de altura
# http://clinicaibed.com.br
# http://www.cycling.com.br
# http://www.sn2.com.br/
# http://www.bikesportbr.com.br
# http://www.biketechbrasilia.com.br
# http://www.superbike101.com.br
# http://www.unibike.com.br
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://www.girabike.com.br
# http://maisbikecompartilhada.com.br/
# http://www.e-vida.org.br
# 1.5
# http://www.konistore.com.br/
# http://www.popobrasil.com
# http://metododeroseasanorte.com.br
# http://www.restaurantexiquexique.com.br/
# http://ru.unb.br/
# http://www.crepeauchocolat.com.br
# http://realpapelaria.com.br
# http://www.popobrasil.com
# C.C.A.A.
# http://islambrasilia.blogspot.com.br
# http://www.celc.org.br
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://www.subway.com.br
# http://donalenha.com.br/
# http://www.livrariamix.com
# http://www.cafeclandestino.com.br
# http://www.ilpandrino.com.br
# http://www.veterinariauberaba.com
# P.M. Formosa
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# Cidade codificada com CEP por logradouros, a partir de 28/11/2014. Sistema de endereçamento: Bairro, quadra, lote.
# http://santoantoniododescoberto.go.gov.br/
# http://www.greens.com.br/
# http://www.caramellaconfeitaria.com.br/
# https://bsbmemo.com/
# http://objetoencontrado.com.br
# http://www.cafedanielbriand.com
# http://amoranatureza.com.br/
# http://www.bikeworlddf.com.br
# http://metododerosesudoeste.com.br
# http://maisbikecompartilhada.com.br/
# http://www.obistroescondido.com.br
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://www.tiogu.com
# http://culturadigital.br/labceus/2014/11/28/aguas-lindas-de-goias/#!/loc=-15.748671815354848,-48.281795382499695,17
# Não é um bairro oficial, mas consta no mapa da cidade como uma área. Precisa de confirmação.
# Não é um bairro oficial, mas consta no mapa da cidade como uma área. Precisa de confirmação.
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# http://www.panetutti.com.br/
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# http://www.bioon.com.br/
# http://www.ebserh.gov.br
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://www.lapalma.com.br/
# Mr. Barber Barbearia
# http://genghiskhan.com.br
# http://www.ispn.org.br
# Barraca temporária de alimentação muito comum em Brasilia. Funciona aos sabados domingos e feriados fornecedno frango assado e outros grelhados na parte da manha até as 13 horas aproximadamente
# www.felts.com.br
# Qd. 12
# http://pastelariavicosa.com.br
# Ad. House Publicidade e Propaganda
# SGAS 910 Bloco H - Ed. Mix Park Sul
# Sl. 127
# http://www.hajimejapanesefood.com
# http://smartfit.com.br
# O CRAS é a principal porta de entrada do Sistema Único de Assistência Social (Suas). Dada sua capilaridade nos territórios, é responsável pela organização e oferta de serviços da Proteção Social Básica nas áreas de vulnerabilidade e risco social.
# http://www.sedest.df.gov.br/
# 3.5
# http://www.aqua710.com.br
# http://www.inctinclusao.com.br/
# 70.919-970
# http://www.brazilianamericanburgers.com.br/
# http://www.grotemarkt.com.br/
# http://www.pinella.com.br
# Minas' cuisine ("cozinha mineira") with cheese bread ("pão-de-queijo") on almost every dish. Great beers and drinks to go along. Authentic brazilian restaurant dedicated to traditional brazilian dishes.
# meidiminas.bsb@gmail.com
# http://calango.club
# Mini pub with some tap beers, not exactly a bar, beer market place.
# https://www.facebook.com/pages/Camberra-cervejas-especiais/1573150019575010
# http://www.facebook.com/AshramLounge/
# http://ticianawerner.com.br
# http://cafecristina.com.br
# http://www.greens.com.br
# http://cafebemcasado.com.br
# MR. GALLO
# http://decurators.org/
# http://www.zeusnightclub.com/site/
# https://www.facebook.com/refresqueideias
# https://www.facebook.com/refresqueideias
# http://openwifi-br.net/
# http://www.dfxsuplementos.com/
# http://www.artefoto.com.br/
# Bebê.com
# http://www.sabin.com.br
# http://maisfiltros.com.br/
# http://yoparticipo.oep.org.bo/
# http://windsorhoteis.com/hotel/windsor-brasilia/
# 2.5
# https://www.facebook.com/pg/gaiaemporio/
# Prefeitura Municipal de Padre Bernardo / GO.
# Prefeitura Municipal de Padre Bernardo / GO.
# http://pt.wikipedia.org/wiki/Torre_de_TV_de_Bras%C3%ADlia
# http://www.funai.gov.br/
# www.anac.gov.br
# http://www.cultura.gov.br
# http://www.facebook.com/h2ecobsb
# Ed. Village de Pituba
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://www.geja.blog.br/
# Sede do Grupo Escoteiro Jose de Anchieta , 11º DF. Atividades todos os sabados de 14:30 as 18:00.
# http://www.granciclismolazzaretti.com.br
# http://endossa.com/
# A Loja.com
# http://f508.com.br
# http://f508.com.br/quintal/
# Top Life resid.
# http://pizzariamarinelle.com.br/
# http://www.caixa.gov.br
# viaesteticabeleza.com.br
# Castanhas.com
# http://www.restaurantexiquexique.com.br
# www.photomidia.com.br
# www.zascar.com.br
# www.jjempilhadeiras.com.br
# http://popofightclub.com.br
# http://dalmoribeiro.com/
# Subway 24h do Jardim Botânico.
# Cond. Quintas Itaipú
# Ponto de Encontro Comunitário (PEC) feito pela Administração Regional do Jardim Botânico, localizado em frente ao Condomínio Quintas Itaipú, aberto à toda comunidade local.
# http://studiolorenaguerra.com.br
# Cond. Quintas Itaipú
# Cond. Chácaras Itaipú
# http://www.softsystem.com.br/
# Cond. Chácaras Itaipú, Ch. 02
# Empresa de Engenharia em Software.
# Local de Hipismo, próximo ao Condomínio Solar de Brasília e à Fazenda Piquet.
# Certamente uma das vistas mais belas do Jardim Botânico e de todo o DF.
# http://endossa.com/
# http://playhotel.com.br/
# facebook.com/restaurantemanati
# www.abrapa.com.br
# Conheça um de nossos cases, o DataSebrae, www.datasebrae.com.br
# Academia de Jiu Jitsu.
# Tele entrega.
# http://www.marcelorocha.com/
# Dr. Cabelo
# CA 05 Ed. Solarium Bloco D Loja 54
# Não possui caixa tradicional.
# Empresa de Informática - Desenvolvimento de Sites, manutenção de computadores, rastreamento veicular e etc.
# Edificio Orion - SHIN CA 05.
# contato@riliongraciebrasilia.com.br
# http://riliongraciebrasilia.com.br/site/
# E.T.C.A
# Tribeca.NY
# copiadoraplanalto@gmail.com
# http://planaltocopiadora.com.br
# denyarj@gmail.com
# http://www.rmater.org.br
# QL 32 SEDB - A.E. 01 - lago sul - Brasília
# http://www.dlurdes.com.br/
# http://www.afbrasilia.org.br/
# http://www.espacomultiplicidade.com.br
# sac@rastreamentobsb.com.br
# http://www.rastreamentobsb.com.br
# CLN 216 BL. A
# http://leidybordados.com.br
# CLN 216 BL. C
# CLN 215 BL. C
# CLN 215 BL. C
# CLN 216 BL. D
# CLN 215 BL. D
# CLN 215 BL. D
# CLN 214 BL. C
# CLN 214 BL. A
# http://www.griffepneus.com.br
# http://www.youmove.com.br/
# Banco do Brasil - Ed. Sede IV - Complexo Central de Tecnologia
# Banco do Brasil - Ed. Sede IV - Complexo Central de Tecnologia
# http://casadascamisetas.com.br/
# http://novatics.com.br/
# montmartre.restaurante@gmail.com
# Quadra 03 conj.3M PLANALTINA DF
# Quadra 03 conj.3M PLANALTINA DF
# Q.I. 14 bloco a comércio local
# http://www.duoorestaurante.com.br/
# ctrlpcartuchos@gmaul.com
# http://harmoniapisos.com.br/
# http://emporiocultural.net.br
# http://www.eadnainternet.com.br
# SGON Quadra 05, Lote 15/18. Asa norte
# raimundo@mendesturbsb.com.br
# http://www.mendesturbsb.com.br
# Ed. Miguel Badya Loja 01
# Mr. Foot
# http://espaco-cultural.webflow.io
# http://cantucci.com.br
# http://www.voiacafe.com.br
# http://www.construporto.com.br
# http://elefantecentrocultural.com
# Mestre-Cervejeiro.com
# http://www.mestre-cervejeiro.com/
# www.pastelariarossoni.com
# http://www.catedralortodoxa.com.br/paroquia-brasilia
# Q. 201 Conj. 20 Casa 07 Residencial Oeste
# http://www.papricaburger.com/
# https://www.instagram.com/clubederemadakaluana/
# http://saborlight.com.br/
# Avenida das Castanheiras, Q. 104 Lotes 1310/1370, Edifício Real Splendor
# http://www.apub.com.br/
# Mr. Pretzels
# http://www.lapalma.com.br/
# LUCAS Experience. Cursos Offroad para todos os tipos de veículos 4x4, viagens e expedições offroad nacionais e internacionais, eventos corporativos automotivos. Brasília, DF.
# luiz.sena@lucasexperience.com.br
# https://www.lucasexperience.com.br/
# https://www.manifestocoworking.com
# https://www.facebook.com/sultanbarbsb/
# https://www.jointheadshopsmoke.com/
# contato@estudiomappa.com
# www.estudiomappa.com
# http://dolcefarnientedf.com.br/
# http://www.cafeeumchero.com.br
# http://www.thebraincoworking.com.br
# 55LAB.store
# http://www.55lab.co
# http://saude.gov.br
# http://www.restaurantechinashow.com.br
# https://www.acaiartesanal.com.br/
# https://www.acaiartesanal.com.br/
# Q. 201 Conjunto 13
# http://www.alub.com.br
# ED. Consei
# anavibkt410@gmail.com
# http://www.theblackbeef.com.br
# http://www.espaco365.com.br
# http://opencoworking.com.br/
# http://www.papomobile.com
# http://co-piloto.me
# http://cobrasilha.com.br
# https://www.thook.com.br
# http://enac.iscv.com.br/
# http://tempoecoarte.com.br
# http://gunga.com.br
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# http://maisbikecompartilhada.com.br/
# Potlatch 0.10
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# Potlatch 0.10f
# http://www.garveyparkhotel.com.br
# http://www.brasiliashopping.com.br/
# http://www.gdf.df.gov.br/042/04299003.asp?ttCD_CHAVE=107233;Bing
# http://www.extra.com.br/Atendimento/LocalizadorLojas.aspx
# http://iesb.br
# secretaria@golfebrasilia.com.br
# http://www.golfebrasilia.com.br/
# 0.0
# http://www.patiobrasil.com.br
# www.planejamento.gov.br
# www.planejamento.gov.br
# http://www.caminheirosbsb.com.br
# http://pt.wikipedia.org/wiki/Pra%C3%A7a_do_Compromisso
# 5.0
# http://www.brasiliapalace.com.br
# http://www.pnse.com.br/
# creascei@sedest.df.gov.br
# http://www.sedest.df.gov.br
# http://www.saude.df.gov.br
# Isto é um setor, transformar em divisão administrativa.
# http://www.df.gov.br/index.php/2016/02/22/memorial-jk/
# SRES AE F, Lt. G
# SGAS Quadra 914 Conj. A Lts 63/64
# http://www.esaf.fazenda.gov.br/
# A.O.S. 8
# A.O.S. 8
# A.O.S. 8
# A.O.S. 8
# A.O.S. 8
# A.O.S. 8
# http://www.prg.df.gov.br
# From Yahoo imagery.
# http://www.emack.com.br/bsb/geral/localizacao.php
# http://www.cmb.ensino.eb.br
# S.H.I.S. C.L. Q.I. 26 Bloco B
# www.superadega.com.br
# SHC/S Qd. 102/103
# Ville de Montagne - Q. 29
# Ville de Montagne - Q. 31
# Ville de Montagne - Q. 31
# Ville de Montagne - Q. 31
# Ville de Montagne - Q. 31
# Ville de Montagne - Q. 31
# Ville de Montagne - Q. 29
# Ville de Montagne - Q. 30
# Ville de Montagne - Q. 30
# Ville de Montagne - Q. 30
# Ville de Montagne - Q. 29
# Ville de Montagne - Q. 29
# Ville de Montagne - Q. 29
# Ville de Montagne - Q. 29
# Ville de Montagne - Q. 30
# Ville de Montagne - Q. 29
# Ville de Montagne - Q. 31
# Ville de Montagne - Q. 31
# Ville de Montagne - Q. 31
# Ville de Montagne - Q. 31
# Ville de Montagne - Q. 31
# Ville de Montagne - Q. 31
# Ville de Montagne - Q. 31
# ...
# Instituto Sociedade, Pulação e Natureza (ISPN)
# Setor de Mansões Dom Bosco (SMDB)
# Setor de Mansões Dom Bosco (SMDB)
# O CRAS é a principal porta de entrada do Sistema Único de Assistência Social (Suas). Dada sua capilaridade nos territórios, é responsável pela organização e oferta de serviços da Proteção Social Básica nas áreas de vulnerabilidade e risco social.
# Minas' cuisine ("cozinha mineira") with cheese bread ("pão-de-queijo") on almost every dish. Great beers and drinks to go along. Authentic brazilian restaurant dedicated to traditional brazilian dishes.
# +55 (61) 3242-3532
# (61)9938-0708
# (61) 3042-7249
# Ministério da Cultura (Anexo)
# Condomínio Morada de Deus (AMOBB)
# Ponto de Encontro Comunitário (PEC) feito pela Administração Regional do Jardim Botânico, localizado em frente ao Condomínio Quintas Itaipú, aberto à toda comunidade local.
# +55 (61) 3427-4949
# +55 (61) 3335-0222
# +55 (61) 98127-3875
# Pronto Atendimento - Emergência (Hospital Brasília)
# PRF - Polícia Rodoviária Federal (COE)
# PRF (COE)
# Associação dos Pilotos de Ultraleve de Brasília (APUB)
# Ponto de ônibus (FS)
# Mário Zinato, faz Toca da Raposa ( Planaltina)
# Mário Zinato, faz Toca da Raposa ( Planaltina)
# (61)37119487
# -1 @ (Mo-Fr 17:30-19:15)
# -1 @ (Mo-Fr 17:30-19:15)
# -1 @ (Mo-Fr 17:30-19:15)
# -1 @ (Mo-Fr 17:30-19:15)
# Rua 4 (Acampamento Rabelo)
# Rua 3 (Acampamento Rabelo)
# Rua 2 (Acampamento Rabelo)
# Rua 1 (Acampamento Rabelo)
# SDS (CONIC)
# Biblioteca Central da UnB (BCE)
# Banco de Brasília (BRB)
# (61) 3585-1924
# 3ª Igreja Presbiteriana de Ceilândia (IPC)
# -1 @ (Mo-Fr 06:00-08:45)
# -1 @ (Mo-Fr 06:00-08:45)
# -1 @ (Mo-Fr 06:00-08:45)
# Fundação de Empreendimentos Científicos e Tecnológicos (FINATEC)
# Centro de Excelência em Turismo (CET)
# Faculdade de Educação (FE-3)
# Faculdade de Educação (FE-5)
# Pavilhão Anisio Teixeira (PAT)
# Pavilhão João Calmon (PJC)
# Museu de Arte de Brasília (MAB)
# pt:Palácio da Justiça (Brasília)
# +55 (61) 3274-0267
# Ville de Montagne - Q 33 (Avenida Comércio)
# Escola Superior de Administração Fazendária (ESAF)
# Estrada Parque Contorno (DF-001)
# Setor de Mansões Dom Bosco (SMDB)
# Setor de Mansões Dom Bosco (SMDB)
# -1 @ (Mo-Fr 17:30-19:15)
# Torre de treinamento(JICA Toko Tower)
# Torre de treinamento((JICA Yokohama Tower))
# Centro Cultural Banco do Brasil (CCBB)
# no @ (Mo-Fr 17:00-19:30)
# AGETOP (http://www.agetop.go.gov.br/post/Vereador /139056/rodovias-de-goias)
# AGETOP (http://www.agetop.go.gov.br/post/Ver/139056/rodovias-de-goias)
# -1 @ (Mo-Fr 06:00-08:45)
# -1 @ (Mo-Fr 17:30-19:15)
# -1 @ (Mo-Fr 17:30-19:15)
# -1 @ (Mo-Fr 06:00-08:45)
# (61) 3901-8363
# Embrapa (Sede)
# Centro de Sensoriamento Remoto (CSR) / PrevFogo / Serviço Florestal Brasileiro (SFB)
# +55 (61) 3244-1660
# Edifício Santa Marta (TRF1)
# Departamento Nacional de Registro do Comércio (DNRC) e Junta Comercial do Distrito Federal (JCDF)
# Justiça Federal - SJDF (1ª a 9ª Vara)
# Secretaria de Orçamento Federal (SOF)
# -1 @ (Mo-Fr 17:30-19:15)
# Embaixada dos Países Baixos (Holanda)
# Sede do Tribunal Superior Eleitoral (TSE)
# Associação do Pessoal da Caixa Econômica Federal do DF (APCEF/DF)
# Acadêmicos da Asa Norte (ARC)
# Instituto de Química (IQ)
# Instituto de Ciências Biológicas (IB)
# O CCB é uma instituição católica fundada em 1975 por iniciativa da Companhia de Jesus (Jesuítas). Promove atividades culturais, religiosas e ações sociais.
# (61) 3426.0400
# Serviço de Limpeza Urbana (SLU)
# Instituto Federal de Brasília (IFB) - Campus Asa Norte
# en:Conjunto Nacional (Brasília)
# Condomínio Morada de Deus (AMOBB)
# Sexto Comando Aéreo Regional (VI COMAR)
# -1 @ (Mo-Fr 06:00-08:45)
# -1 @ (Mo-Fr 17:30-19:15)
# -1 @ (Mo-Fr 17:30-19:15)
# -1 @ (Mo-Fr 06:00-08:45)
# -1 @ (Mo-Fr 06:00-08:45)
# -1 @ (Mo-Fr 06:00-08:45)
# -1 @ (Mo-Fr 17:30-19:15)
# -1 @ (Mo-Fr 17:30-19:15)
# Rua 3 (Travessa A)
# Rua Pedro José Fernandes (Rua do Matadouro)
# Tipo (rua) não oficial
# BSGI (Budismo Nitiren)
# Colégio Marista (Maristão)
# Laboratório de Estudos Geodinâmicos e Ambientais (LEGA) / Laboratório de Geocronologia
# Confederação Nacional da Indústria (CNI)
# Confederação Nacional do Comércio (CNC)
# -1 @ (Mo-Fr 06:00-08:45)
# -1 @ (Mo-Fr 17:30-19:15)
# -1 @ (Mo-Fr 06:00-08:45)
# -1 @ (Mo-Fr 17:30-19:15)
# Unidade de Ensino e Docência (UED) - FCe
# Unidade Acadêmica (UAC) - FCe
# Módulo de Serviços e Equipamentos Esportivos (MESP) - FCe
# pt:Praça do DI (Taguatinga)
# pt:Praça do Relógio (Taguatinga)
# Bloco de Salas de Aula Norte Eudoro de Souza (BAES)
# +55 (61) 3427-2101
# Escola Superior de Administração Fazendária (ESAF)
# Antiga Diretoria Regional de Ensino de Ceilândia (Desativada)
# (61) 33820094
# No mapa da SEDHAB consta como Via 3, mas pela sequência lógica esta (a Via 3) se localiza depois da via 2.
# Observatorio Meteorologico de Brasilia (OMBRA)
# Instituto de Química (IQ)
# Setor de Mansões Dom Bosco (SMDB)
# Diretoria de Vigilância Ambiental (Dival)
# Estrada (Acesso ao Frigorífico Formosa)
# Faculdade de Educação Física (FEF)
# Casa do Estudante Universitário (CEU) - Bloco A
# Campus Universitário Darcy Ribeiro (Gleba B)
# Casa do Estudante Universitário (CEU) - Bloco B
# Campus Universitário Darcy Ribeiro (Gleba B)
# Praça Cívica (Praça dos Cristais)
# Estação Estrada Parque (em construção)
# (p/ terceira idade)
# Faculdade de Administração, Contabilidade e Economia (FACE)
# Centro de Ensino Fundamental de Ceilândia (desativado)
# +55 (61) 3107-8901
# +55 (61) 3107-8901
# Bloco de Salas de Aula Sul (BSA)
# +55 (61) 3357-4721
# (61) 3357-4721
# Centro de Apoio ao Desenvolvimento Tecnológico (CDT)
# Centro de Manutenção de Equipamentos Científicos (CME)
# Centro de Informática (CPD)
# Centro de Referência em Conservação da Natureza e Recuperação de Áreas Degradadas (CRAD)
# Córrego do Pasto (afluente)
# Acesso ao DETRAN Sede (estacionamento)
# no @ (Mo-Fr 17:00-19:30)
# no @ (Mo-Fr 17:00-19:30)
# Rua Anápolis (Antiga Avenida Aeroporto)
# +55 (61) 3427-4081
# +55 (61) 3427-1512
# +55 (61)3427-2052
# +55 (62) 3981-1192
# (61) 3432-2425
# 61) 3432-2108 / 3981-1149
# (61) 3642-4176
# Rua São Pedro (esquina com Rua 2)
# (61) 3642 1483 / 3981 1150
# Estrada de Acesso (Fazenda do sr. Eli)
# Estrada - acesso ao Frigorífico Bom Corte (Frivale)
# Estrada (Acesso ao Frigorífico Formosa)
# Estrada de Acesso (Fazenda do sr. Eli)
# Instituto de Ciência Política / Instituto de Relações Internacionais (IPOL/IREL)
# Departamento de Ciência da Computação / Departamento de Estatística (CIC/EST)
# Instituto de Ciências Sociais (ICS)
# Bloco de Salas de Aula Norte (BSAN)
# yes @ (Mo-Fr 06:00-08:45)
# pt:Ilha do Retiro (Brasília)
# Hospital Regional da Asa Norte (HRAN)
# Quadra 07, lote 01, EPCT, Taguatinga (DF)
# Centro de Ensino Médio Integrado do Gama (CEMI)
# Área de Eventos - Sede (Ouro Vermelho 1)
# Churrasqueira (Ouro Vermelho 1)
# Administração (Condomínio Verde)
# AGETOP (http://www.agetop.go.gov.br/post/Ver/139056/rodovias-de-goias)
# Beco (alley)
# -1 @ (Mo-Fr 06:00-08:45)
# Lado Sul (Embarque Circulares)
# -1 @ (Mo-Fr 17:30-19:15)
# -1 @ (Mo-Fr 06:00-08:45)
# yes @ (Mo-Fr 06:00-08:45)
# yes @ (Mo-Fr 06:00-08:45)
# yes @ (Mo-Fr 06:00-08:45)
# +55 (61) 3246 9763
# Instituto Federal de Brasília (IFB) - Campus São Sebastião
# Rua 5 (Forquilha Encravada) - Altiplano Leste
# Sítio das Oliveiras (Via Professor João Ribeiro) - Chácaras 1 a 21
# Setor de Mansões Dom Bosco (SMDB)
# Administração (Ouro Vermelho 1)
# Centro Interdisciplinar de Estudos em Transportes (CEFTRU)
# Oleoduto São Paulo - Brasília (OSBRA)
# Condomínio Vale dos Pinheiros (Sobradinho)
# Condomínio Vale dos Pinheiros (Sobradinho)
# Proteção ambiental do Planalto central (CERRADO)
# Luzes de aproximação do Aeroporto Internacional de Brasília (SBBR)
# Luzes de aproximação do Aeroporto Internacional de Brasília (SBBR)
# pt:Planaltina (Goiás)
# pt:Formosa (Goiás)
# pt:Distrito Federal (Brasil)
# 312 - Setor O/ Rodoviária do Plano Piloto (via Estrutural)
# 382 - Setor O/Rodoviária do Plano Piloto (via Leste/Estrutural)
# 107 - Rodoviária do Plano Piloto/W3-L2 Sul (Esplanada)
# pt:Plano Piloto (região administrativa)
# pt:Cruzeiro (Distrito Federal)
# pt:Gama (Distrito Federal)
# pt:Guará (Distrito Federal)
# pt:Itapoã (Distrito Federal)
# pt:Jardim Botânico (Distrito Federal)
# pt:Planaltina (Distrito Federal)
# pt:Samambaia (Distrito Federal)
# pt:Santa Maria (Distrito Federal)
# pt:Sobradinho (Distrito Federal)
# pt:São Sebastião (Distrito Federal)
# pt:Taguatinga (Distrito Federal)
# pt:Varjão (Distrito Federal)
# pt:Águas Claras (Distrito Federal)
# 0.169 - Cruzeiro/W3 Norte (Buriti-Avenida Comercial Sudoeste)
# Cruzeiro/W3 Norte (Buriti-Avenida Comercial Sudoeste)
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# +55 (61) 3033-3117
# Atenção: é um bairro que não está ocupado ainda, mas já existe projeto para ele, com todas as quadras definidas. Favor não alterar os seus limites por achar que não existe nada no local. Antes de alterar sem conhecimento, favor me consultar (Ivaldo).
# 0.168 - Cruzeiro / Sudoeste / L2 Norte (UnB)
# 0.024 - Cruzeiro / Sudoeste / Esplanada (CNB)
# Faculdade de Direito (FD)
# 183.2 - CIRCULAR - São Sebastião (res. bosque)/ Vila do Boa/ Condomínios (ESAF)
# Faculdade de Ciências da Saúde (FS)
# '  ---------------------------------------------
# Alfredo's
# McDonald's
# Caixa d'Água
# Snook Drink's
# Family's Hair
# McDonald's
# Fróe's Burguer
# Morgana's Caldos
# Brokado's
# Domino's Pizza
# O'Rilley Irish Pub
# C'est la Vie
# Gate's Lounge Bar
# Habib's
# McDonald's
# McDonald's
# McDonald's
# McDonald's
# DriveThru McDonald's Taguatinga Centro
# 'A Justiça'
# Thiago's Show de Carnes
# bike'n FIX
# D'Vilela Restaurante e Café
# Bob's
# L'Entrecôte de Paris
# Fran's Café
# Açougue Boi D'ouro
# Parque Olhos d'Água
# Domino's Pizza
# D'Lav
# Mitto's
# Paper's Line
# C'est si bon
# D'Vilella
# Du'Cheff
# McDonald's
# Habib's
# Kabana's
# Minas' cuisine ("cozinha mineira") with cheese bread ("pão-de-queijo") on almost every dish. Great beers and drinks to go along. Authentic brazilian restaurant dedicated to traditional brazilian dishes.
# Green's Restaurante Natural
# Bito's Bar
# Good's
# Moreno's Restaurante
# Rosa's Café
# D'Lurdes
# Fran's Café
# Bob's
# MacDonald's
# Point D'Cavalcante
# Mariart's Festas
# Virginia D'Arc
# Jhonny's Car
# Neiva's Auto
# Brito's Restaurante
# Maison Maxim's Cozinhas & Armários
# Domino's Pizza
# McDonald's
# Dubay's
# Dubry's Fast Food
# D'Lurdes
# Dunkin' Donuts
# Nad'arte
# Centro Educacional D'Paula
# Fran's Café
# Fran's Café
# Fran's Café
# McDonald's
# Luk's
# Pirata's
# L' amour du Pain
# Sam's Club
# McDonald's
# Brou'ne
# 13th Site Lorenzo's Pub
# McDonald's
# Bob's
# QUINTAL DI'CASA BISTRÔ DE RUA
# Fran's Café
# Fran's Café
# Alexandre's
# Domino's Pizza
# Clean 'n Dry
# Bob's
# Bob's
# Parque Olhos d'Água
# pt:Parque Olhos D'Água
# McDonald's
# McDonald's
# Recanto Olhos D'Água
# Kitchen's
# Habib's
# Ambaixada d'Espanya
# Ambassade de États-Unis d'Amérique
# Ambasciata d'Italia
# Ambassade de Côte-d'Ivoire
# Córrego Poço d'Ánta
# Córrego Poço d'Água
# McDonald's
# McDonald's
# McDonald's
# Ed. Palazzo D'Alberi
# SQNW 111 Bloco A - Edifício Via Cote D'Azur
# SQNW 311 Bloco D - Edifício Atrium D'or
# Edifício Atrium D'or
# SQNW 311 Bloco E - Edifício Atrium D'Argent
# Edifício Atrium D'Argent
# McDonald's
# McDonald's
# McDonald's
# Du'Lar
# Rock'n Gol
# Residencial Paineiras'
# Mansões Recreio Estrela D'alva
# Casa d'Italia
# Córrego Olho D'água
# Escola Classe Mestre D'armas
# FABRICA DE CAIXA D'AGUA
# Escola Classe Olhos D'Agua
# Drive-thru do McDonald's
# Ambassade d'Inde
# religion was Católica_Ortodoxa -- couldn't find it in listed denominations - https://wiki.openstreetmap.org/wiki/Key:denomination
# Espelho d'água do Teatro
# Fazenda Retiro dos Olhos d'Água
# razgu'e
# מינאס ז'ראיס
# Markaziy-g'arbiy hudud
# &  ---------------------------------------------
# Zoe Pizzaria & Steak
# Sabor & Companhia
# Dolce & Baccana NightClub
# Tok & Retok
# Bolos & Cakes
# Duda & Janot Boutique
# Kombinado Bistrô & Bar
# Soares & Souza
# Colchões & Colchões
# Viçosa Pastel & Pizza Bar
# Casa & Reparos
# Filé & Tal Express
# Deise & Dora
# Ótica M&Z
# C&A
# Vet & Pet
# Casa & Festa
# J&R
# 3M Games & Informática
# Maison Maxim's Cozinhas & Armários
# Cabelo & Cia
# Harmonia - Pisos & Decorações
# Track & Field
# Farma & Farma
# Vó Ía Café & Empório
# Dom Espeto & Dona Brasa
# C&A
# Tu & Tica
# Metrópole Shopping & Residência
# Atrium Residence & Lofts
# Toronto Mall & Residence
# Park Style Mall & Residence
# Blend Apartments & Brookfield Store
# Quebec Residence & Mall
# Figueiras Residencial & Mall
# BB Tecnologia & Serviços
# Trow Parrilla & Beer
# Pullman & Bimbo S.A
# "  ---------------------------------------------
# Etapa "A"
# Minas' cuisine ("cozinha mineira") with cheese bread ("pão-de-queijo") on almost every dish. Great beers and drinks to go along. Authentic brazilian restaurant dedicated to traditional brazilian dishes.
# Seminario Missionário Arquidiocesano "Redemptoris Mater"
# Casa de Convivências "Sagrada Família de Nazaré"
# Casa de Convivências "Sagrada Família de Nazaré"
# Parque Vivencial do Setor "O"
# QNN 30, Área Especial "J"
# QNN 30, Área Especial "J"
# Setor "O"
# Estacionamento dos Blocos "D" e "F" da SQN 213
# #  ---------------------------------------------
# http://culturadigital.br/labceus/2014/11/28/aguas-lindas-de-goias/#!/loc=-15.748671815354848,-48.281795382499695,17
# #C0C0C0
# #bf974a
# #7a7a7a
# #C0C0C0
# #5c5750
# #c0a481
# #86734f
# #3366FF
# #3366FF
# #4169E1
# #4169E1
# #fffb81
# #92e1c0
# #ffe37f
# #4986e7
# #5c5750
# #c0a481
# $  ---------------------------------------------
# Estacionamento Até 01 hora - R$ 7,00 Até 02 horas - R$ 10,00 Até 03 horas - R$ 12,00 Até 04 horas - R$ 14,00 Até 05 horas - R$ 16,00 Até 06 horas - R$ 18,00 Até 07 horas - R$ 20,00 Até 08 horas - R$ 22,00 Até 09 horas - R$ 24,00 Até 10 horas - R$ 26,00
# !  ---------------------------------------------
# Hum! Burger
# http://culturadigital.br/labceus/2014/11/28/aguas-lindas-de-goias/#!/loc=-15.748671815354848,-48.281795382499695,17
# FAVOR NÃO DELETAR! Este trecho permite verificar a integridade da relação ao longo de toda a rodovia.
# FAVOR NÃO DELETAR! Este trecho permite verificar a integridade da relação ao longo de toda a rodovia.
# FAVOR NÃO DELETAR! Este trecho permite verificar a integridade da relação ao longo de toda a rodovia.
# Maybe a sports pitch? Check out the usage!
# Esta via NUNCA é usada no sentido da EPCL->EPIA!
# =  ---------------------------------------------
# http://cnes.datasus.gov.br/Exibe_Ficha_Estabelecimento.asp?VCo_Unidade=5219752437627
# http://culturadigital.br/labceus/2014/11/28/aguas-lindas-de-goias/#!/loc=-15.748671815354848,-48.281795382499695,17
# http://www.gdf.df.gov.br/042/04299003.asp?ttCD_CHAVE=107233;Bing
# http://www.fhb.df.gov.br/003/00318002.asp?ttCD_CHAVE=6626
# ]  ---------------------------------------------
# Datacenter Banco do Brasil]
# >  ---------------------------------------------
# Esta via NUNCA é usada no sentido da EPCL->EPIA!

# %% [markdown]
# ### Check different street names abbreviations
#
# ##### Regular Expressions

# %%
street_type_re = re.compile(r'^\S+\.?', re.IGNORECASE)

# %% [markdown]
# ##### Functions
# _from lesson 5 "Data Quality", "8. Exemplo Utilizando Nossas Melhores Práticas". Adapted_

# %%
street_types = defaultdict(int)

def audit_street_type(street_types, street_name):
    """Get the first word of the attribute and add counter to the list"""
    
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        street_types[street_type] += 1

def print_sorted_dict_by_key(d):
    """Print the dictionary sorted by key value"""
    
    keys = d.keys()
    keys = sorted(keys, key=lambda s: s.lower())
    for k in keys:
        v = d[k]
        print "%s: %d" % (k, v) 

def is_street_name(elem):
    """Check if the element is from the tag 'tag' and the attribute 'k' is addr:street"""
    
    return (elem.tag == "tag") and (elem.attrib['k'] == "addr:street")

def audit_street_k(filename):
    """List the first word (with or without dot) of the addr:street attribute with the number of occurrences"""
    
    for event, elem in ET.iterparse(filename):
        if is_street_name(elem):
            audit_street_type(street_types, elem.attrib['v'])    
    print_sorted_dict_by_key(street_types)

# %% [markdown]
# ##### Callers

# %%
# get the first word and number of occurrences of attribute "v" when "k" == "addr:street"
audit_street_k(OSM_FILE)
# Out:
# 2: 1
# 203: 1
# 506/507: 1
# 508: 1
# 508-509: 1
# 508/509: 1
# 510: 1
# 713/913: 1
# 8: 1
# A.O.S.: 6
# Academia: 1
# ADE: 1
# AE: 4
# AENW: 1
# Aeroporto: 1
# Alameda: 3
# AR: 2
# Area: 1
# ASBAC: 1
# AV.COMERCIAL: 1
# Avenida: 282
# Bloco: 1
# BR-020: 1
# BR060: 2
# BR070: 2
# Brasília: 1
# C1: 1
# C7: 2
# CA: 45
# Campus: 11
# CCSW: 13
# Centro: 4
# Chácara: 1
# CL: 1
# Cln: 19
# CLN: 247
# CLNW: 6
# CLRN: 2
# Cls: 64
# CLS: 58
# Clsw: 2
# CLSW: 64
# CMA: 1
# CNB: 14
# CNF: 2
# CNM: 10
# Colonia: 1
# Cond.: 16
# Condomínio: 50
# Conjunto: 1
# conjunto: 1
# CRN: 1
# CRNW: 1
# CRS: 1
# Crs: 1
# Cruzeiro: 1
# CSA: 1
# CSB: 1
# CSG: 1
# CSG04: 1
# DF: 1
# DF-095: 1
# DF-140: 1
# ED.: 1
# Edificio: 2
# Eixo: 21
# EPIA: 1
# EPTG: 9
# EQ: 4
# EQL: 2
# EQN: 5
# EQNM: 1
# EQNO: 2
# EQNP: 3
# Eqs: 1
# EQS: 6
# EQSW: 2
# Esplanada: 1
# EST: 1
# Estacionamento: 2
# Estrada: 9
# Estância: 2
# Etapa: 1
# Feira: 1
# Ginásio: 1
# HCGN: 5
# Hospital: 1
# Incra: 1
# INCT: 1
# INMET: 1
# L2: 3
# Marginal: 1
# ML: 1
# Núcleo: 19
# Palácio: 1
# Parque: 1
# Pistão: 2
# Praça: 7
# Q: 2
# Q.: 2
# Q.I.: 1
# Qd.: 1
# QE: 7
# QI: 44
# QI33: 1
# QL: 1
# QMSW: 14
# Qn: 12
# QN: 34
# QNA: 6
# QNB: 2
# QND: 2
# QNF: 1
# QNG: 3
# Qnl: 2
# Qnm: 26
# QNM: 25
# QNN: 4
# Qno: 1
# QNO: 4
# QNP: 4
# QNQ: 1
# Qr: 1
# QR: 9
# QRSW: 4
# Qs: 1
# QS: 8
# Qs309/307: 1
# QSA: 3
# QSB: 1
# QSD: 4
# QSE: 1
# Quadara1: 1
# QUADRA: 1
# Quadra: 348
# Quadra4: 1
# Rod.: 1
# Rodovia: 3
# Rua: 293
# rua: 3
# S.H.I.S.: 1
# SAA: 1
# SAAN: 1
# SAF: 2
# SAFS: 5
# SAIN: 2
# SAIS: 1
# SAIS,: 1
# SAM: 1
# SAS: 3
# Sas: 1
# SAUN: 1
# SAUS: 10
# SBN: 2
# SBN,: 1
# SBS: 2
# SCEN: 3
# SCES: 14
# SCES,: 1
# SCHCES: 1
# SCHES: 4
# SCHF: 1
# SCIA: 2
# SCLRN: 8
# SCLS: 1
# SCN: 4
# SCRN: 20
# SCRS: 1
# SCS: 20
# SDE: 10
# Segunda: 1
# SEP: 1
# SEPN: 6
# SEPS: 8
# SES: 4
# SES,: 1
# Setor: 19
# Setores: 1
# SGAN: 7
# SGAS: 37
# SGCV: 1
# SGO: 1
# SGON: 1
# SHA: 2
# SHC: 1
# SHC/S: 1
# SHCES: 1
# SHCGN: 21
# SHCGN-CR: 1
# SHIN: 21
# SHIS: 40
# SHIS,: 2
# SHLN: 1
# SHLS: 2
# SHMA: 1
# SHN: 5
# Shopping: 2
# SHS: 1
# SHTN: 1
# SHVP: 1
# SIA: 47
# SIbs: 1
# SIG: 20
# SMDB: 1
# SMHS: 1
# SMIN: 1
# SMPW: 7
# SOF: 1
# SOPI: 1
# SPMN,: 1
# SQN: 79
# sqnw: 1
# SQNW: 45
# SQS: 85
# SQSW: 4
# SRES: 3
# SRIA: 1
# SRT: 1
# SRTVS: 4
# STN: 3
# São: 1
# Trecho: 1
# UnB: 4
# Via: 6
# via: 1
# Ville: 50
# W2: 3
# W3: 2
# W5: 2
# Águas: 1
# Área: 12

# %% [markdown]
# ### Note:
# * The Brasilia city has a lot of abbreviations on addresses. This is the common way of describing addresses on the city, so the most relevant abbreviations to correct are: Rua, Avenida, Quadra, Condominio, Edificio, Setor e Companhia.

# %% [markdown]
# ### Find street abbreviations on the tags
# ##### Functions

# %%
def get_street_name(street_name):
    """Get the first word (with or without '.'), as defined by the regular expression, of the string"""
    
    m = street_type_re.search(street_name)
    if m:
        return m.group()
    
def is_tag(element):
    """Check if the tag of the element is 'tag'"""
    
    return element.tag == 'tag'
    
    
def audit_street(filename, values_list):
    """List how many tag attribute "v" words matches the defined list by tag attribute 'k'"""
    
    street_names_attr = defaultdict(dict)
    for _, element in ET.iterparse(filename):
        if is_tag(element):
            for attribute in element.attrib:
                attr_value = get_street_name(element.attrib[attribute])
                if attr_value.lower() in values_list:
                    if attr_value in street_names_attr[element.attrib['k']]:
                        street_names_attr[element.attrib['k']][attr_value] += 1
                    else:
                        street_names_attr[element.attrib['k']][attr_value] = 1

    return street_names_attr

# %% [markdown]
# ##### Callers

# %%
# get the "v" attribute matches occurrences on street abbreviation list by "k" attribute
street_abbr = ['avenida', 'av', 'av.', 'av:', 'rua, ''r', 'r.', 'r:', 'quadra', 'q', 'q.', 'qd', 'qd.', 'qd:', 'condominio', u'condomínio', 'cond', 'cond.', 'cond:', 'edificio', u'edifício', 'ed', 'ed.', 'ed:', 'setor', 'st', 'st.', 'st:', 'companhia', 'cia', 'cia.', 'cia:']
pprint.pprint(dict(audit_street(OSM_FILE, street_abbr)))
# Out:
# {'addr:full': {u'Avenida': 2},
#  'addr:housename': {u'Condom\xednio': 1,
#                     u'Ed.': 1,
#                     u'Edif\xedcio': 51,
#                     'QD.': 1,
#                     'Quadra': 1},
#  'addr:housenumber': {'Ed.': 1, 'Q': 1, 'Qd': 1, 'Quadra': 6},
#  'addr:place': {u'Avenida': 1, 'Setor': 10},
#  'addr:street': {'Avenida': 282,
#                  u'Cond.': 16,
#                  u'Condom\xednio': 50,
#                  'ED.': 1,
#                  'Edificio': 2,
#                  'Q': 2,
#                  'Q.': 2,
#                  'QUADRA': 1,
#                  'Qd.': 1,
#                  u'Quadra': 348,
#                  'Setor': 19},
#  'addr:suburb': {u'Condom\xednio': 1, 'Setor': 102},
#  'alt_name': {'Avenida': 3,
#               u'Condom\xednio': 3,
#               'Edificio': 1,
#               u'Edif\xedcio': 5,
#               'Quadra': 2,
#               'Setor': 11},
#  'description': {'Condominio': 1, u'Condom\xednio': 1, u'Edif\xedcio': 1},
#  'destination': {'Setor': 1},
#  'from': {'Setor': 2},
#  'leisure': {'quadra': 1},
#  'name': {'AV:': 32,
#           'Av': 8,
#           'Av.': 14,
#           'Av:': 29,
#           'Avenida': 1017,
#           'CIA': 1,
#           'COND.': 7,
#           'Cia': 6,
#           'Cia.': 1,
#           'Companhia': 7,
#           u'Cond.': 38,
#           'Condominio': 13,
#           u'Condom\xednio': 161,
#           'Ed': 1,
#           'Ed.': 2,
#           'Edificio': 53,
#           u'Edif\xedcio': 202,
#           'Q': 5,
#           'Q.': 2,
#           'Qd.': 12,
#           'Quadra': 1057,
#           'R:': 248,
#           'Setor': 311,
#           'St': 1,
#           'St.': 3,
#           'avenida': 2,
#           'quadra': 56},
#  'name:pt': {u'Condom\xednio': 4, 'Ed': 1, u'Edif\xedcio': 1, 'Quadra': 1},
#  'note': {'Ed.': 8},
#  'official_name': {u'Condom\xednio': 1,
#                    'Edificio': 1,
#                    u'Edif\xedcio': 1,
#                    u'Setor': 15},
#  'old_name': {'Avenida': 3},
#  'operator': {'Companhia': 1, u'Condom\xednio': 4, 'Setor': 2},
#  'seamark:light:character': {'Q': 2}}

# %% [markdown]
# ### Check "v" values patterns
#
# ##### Regular Expressions

# %%
postal_code_re = re.compile(r'^\d{5}-\d{3}$')
phone_re = re.compile(r'^(\+55 61 9?\d{4}-\d{4})(;\+55 61 9?\d{4}-\d{4})*$') # one or more telephone occurences with ; as delimiter
email_re = re.compile(r'^[\w.-]+@[_\w-]+\.[_\w-]+(\.[_\w-]+)*$')
site_re = re.compile(r'^https?://[_\w-]+\.[_\w-]+((\.|/)?[_\w-]+)*/?$')
opening_hours_re = re.compile(r'(^([A-Z][a-z](-[A-Z][a-z])? \d\d:\d\d-\d\d:\d\d)+(; ?([A-Z][a-z](-[A-Z][a-z])? \d\d:\d\d-\d\d:\d\d))*$)|(^24/7$)')

# %% [markdown]
# ##### Functions

# %%
def match_pattern(value, pattern_re, pattern_counter):
    """Count the number of matches and not matches of a value by given regular expression"""
    
    m = pattern_re.match(value)
    if m:
        pattern_counter['match'] += 1
    else:
        pattern_counter['no match'] += 1
        print value
    return pattern_counter
    
def is_attribute(element, k_value):
    """Check if the element tag attribute "k" matches the k_value"""
    
    return (element.tag == 'tag') and (element.attrib['k'] == k_value)
    
def check_patterns(filename, k_value, pattern_re):
    """Check number of regular expression patterns occurrences on the xml file by "k" attribute value"""
    
    pattern_counter = defaultdict(int)
    for _, element in ET.iterparse(filename):
        if is_attribute(element, k_value):
            pattern_counter = match_pattern(element.attrib['v'], pattern_re, pattern_counter)
    return pattern_counter

# %% [markdown]
# ##### Callers

# %%
# look for the number of postal code correct pattern on the "k" attribute "addr:postcode"
attribute = "addr:postcode"
pattern_re = postal_code_re
print check_patterns(OSM_FILE, attribute, pattern_re)
# Out:
# 71.961-540
# 71060230
# 72225971
# 71050041
# 71996075
# 71060230
# 72215-035‎
# 73100210
# 71215267
# 70716901
# 72910000
# 70390100
# 71060230
# 71060230
# 71060230
# 71060230
# 71060230
# 71060230
# 71060230
# 71060230
# 71060230
# 71060230
# 71060230
# 71060230
# 70.919-970
# 72231206
# 72215058
# 72215032
# 71735300
# 70855 520
# 72130095
# 72280184
# 71735300
# 72215963
# 70875510
# 71250005
# 70852520
# 71705521
# 73062507
# 72110789
# 70046900
# 70040906
# 70660045
# 87200110
# 70675426
# 70675427
# 70347090
# 70853530
# 70757040
# 715035-02
# 71503505
# 71060230
# 70740776
# 70670405
# 70658472
# 70.686-420
# 70.752-060
# 70.686-405
# 70.687-145
# 70.687-135
# 70.687-140
# 70.687-310
# 70.687-305
# 70.686-710
# 70.86-705
# 70.687-330
# 70.686-750
# 70.686-625
# 70.686-620
# 70.686-615
# 70.686-610
# 70.686-605
# 70.686-525
# 70.687-210
# 70.687-215
# 70.687-245
# 70.687-120
# 70.687-110
# 70.686-550
# 70.686-440
# 70.686-535
# 70.686-510
# 70.686-190
# 70.686-195
# 70.686-180
# 70.686-185
# 70.686-155
# 70.687-150
# 70.686-820
# 70.686-815
# 70.686-805
# 70.686-065
# 70.686-055
# 70.686-715
# 70.686-720
# 70.687-230
# 70.686-070
# 70.686-075
# 72255203
# 71929360
# 70740762
# 70740764
# 72140588
# 72720100
# 72.220-310
# 72215509
# 72255203
# 70711900
# 71936250
# 70680415
# 71015124
# 71918000
# 72312401
# 70740777
# 71680390
# 71680390
# 71680390
# 71680364
# 70770731
# 71907360
# 71938360
# 72700000
# 70.701-010
# 71560100
# 71910360
# 72870408
# 73050151
# 73045105
# 73045100
# 71250720
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73045151
# 73088
# 72231406
# 72231
# 72255203
# 72255203
# defaultdict(<type 'int'>, {'no match': 202, 'match': 548})

# %%
# look for the number of postal code correct pattern on the "k" attribute "postal_code"
attribute = "postal_code"
pattern_re = postal_code_re
print check_patterns(OSM_FILE, attribute, pattern_re)
# Out:
# 71901300
# 71996075
# 73040135
# 73040133
# 73045170
# 73040134
# 73045155
# 73040137
# 73050182
# 73045152
# 73050185
# 73050187
# 73050186
# 73050184
# 73045173
# 73040132
# 73045151
# 73045169
# 73050196
# 73045153
# 73040136
# 73050176
# 73050163
# 73045174
# 73050173
# 73040138
# 73045154
# 73050166
# 73050177
# 73050164
# 73045171
# 73045172
# 73050178
# 73050194
# 73045167
# 73050193
# 73050174
# 73045172
# 73050175
# 73050181
# 73050166
# 73050190
# 73045171
# 73050162
# 73050183
# 73050161
# 71906500
# 71680348
# 73040131
# 73045175
# 73050191
# 73050192
# 73050195
# 73050189
# 73050188
# 73045168
# 73050165
# defaultdict(<type 'int'>, {'no match': 57, 'match': 124})

# %%
# look for the number of telephone correct pattern on the "k" attribute "phone"
attribute = "phone"
pattern_re = phone_re
print check_patterns(OSM_FILE, attribute, pattern_re)
# Out:
# (61) 99309-0100
# 61 3367-4814
# (61)3335-8776
# (61)3427-1539
# (61)3427-2009
# +55 61 33271108
# 32342113
# 3361-0813
# 3399-2250
# 3399-2031/ 3064
# (61) 33820446
# (61) 3381-3444
# (61) 3381-3837 ou 3573-4344
# (61) 3381-3444
# +55 61 33018000
# +55 61 32084128
# +556135510001
# 61 33191111
# +55 61 30337707
# +55 61 34271730
# +55 61 30325774
# 613556-7622
# 6133840074
# 6132740534
# 6135567744
# 6132743007
# 6185761017
# 6133855718
# 6133844420
# 6135564669
# 6133851054
# 6184173870
# 6133843666
# 6135561005
# 6133842636
# 6139676716
# 6133855404
# 6133842267
# 6134842165
# 6135560095
# 6133843675
# 34845419
# 6134845876
# 6133849275
# 6135560102
# 6135563983
# 6133844574
# 6184125474
# 615564660
# 6139679732
# 6133843788
# 6135564030
# 6191060648
# 6199973864
# 6196220454 ou 84825119
# 92316199
# 6192192324
# 6133846494
# 6130416775
# 6130224274
# 6134842910
# 6133851770
# 6135569645
# 6130365663
# 6133841644
# 6133857759
# 6133844954
# 6132017493
# 6134847635
# 6133851900
# 6130377604
# 6133853343
# 6130368449
# 6133850888
# 6130410585
# 6135560534
# 6133851722
# 6134848985
# 615561083
# 6130337171
# 6133845857
# 6133840227
# 6135562525
# 6133841901
# 6135560607
# 6133850817
# 34842492
# 6135562602
# 6133850330
# 6133845326
# 6184354155
# 6184548121
# 6133854081
# 6133858234
# 614840149
# 6135560010
# 6130416772
# 6134847569
# 616133843171
# 614847427
# 6133850783
# 6130344516
# 6134845421
# 6139672228
# 6133850904
# 6141415514
# 6133851432
# 6135563811
# 6133846382
# 6130213493
# 6155613385
# 6133843938
# 6135565652
# 6135564032
# 6135562324
# 6134848047
# 6135563989
# 6130332747
# 6132747781
# 61 35565344
# 6130452062
# 6132731880
# 614845971
# 30335204
# 6135560282
# 6133848288
# 6133848884
# 6133841863
# 6133847128
# 6133851055
# 6133843366
# 6133858311
# 6133849580
# 613384-7373
# 6133844509
# 6133845593
# 3484 9500 e 3484 9528
# 6139678866
# 6134849000
# 6133853761
# 6133850062
# 6133856166
# 6135327222
# 6130213629
# 6130314466
# 6134841313
# 3484-9100
# 6191019591
# 6133849593
# 6132728713
# 6135561355
# 6133854295
# 6134842651
# 6134848071
# 6133849566
# 6134847715
# 6133848550
# 6134840076
# 6133847063
# 6130324525
# 6134840865
# 6133844060
# 6135564444
# 3556-5236
# 6133856416
# 33933889
# 33933451
# 3471-1500
# 3372-4555
# 3373-0002
# 3379 9100 e 3379 9128
# 3379-9526
# 6133912999
# 6133915207
# 6133911577
# 6134796112
# 3359 9300
# 6133582144
# 6133331645
# 6134585608
# 6133330166
# 33334740
# 6134042158
# 6133586565
# 6133587506
# 6133333332
# 6133738640
# 6133343047
# 6134582651
# 6133571051
# 6134340006
# 6134341099
# 6134585302
# 6133584888
# 6130466667
# 33338000
# +55-61-3434-3707
# 6134347004
# 6133334684
# 6133331222
# 34341077
# 6134344086
# 6134044326
# 6133336666
# 6133570343
# 6134340906
# 34347708
# 6134586696
# 33330536
# 6133336000
# 6133577673
# +55 61 33582061
# 6134347106
# 6133333339
# 3332 9000 e 3332 9028
# 3357 9100 e 3357 9128
# 6134042915
# 6133337092
# 6130412010
# 61-3357-6916
# +55 61 33580458
# 6133573000
# 613357950
# 6134345675
# 33337760
# 6130412015
# 6134346181
# +55 61 34585063
# 6130367447
# 6133343443
# 6133820663
# 6133638409
# 6133464288
# 6133639406
# 6133638360
# (61) 3363-9705
# 6133639116
# 6134351125
# 6133638847
# 6133638056
# 61 3322-4000
# 61 3223-0187 4141-4126
# 61 3316-6285 3316-6265
# 3226 2005 e 3224 8429
# 3226 9880
# 61 3356-4730
# 61 2107 0202
# 61 3389-2243 Ramal 140
# 3347-9838
# 61 2103-8484
# +55 61 33837828
# 06135677624
# 3901 2635
# 61 3273-0958
# 3248-2450
# 3248-4768
# 3242 9087
# 3366-1800 E 3366-3033
# 6133015870
# (61) 3427-1100
# 3301 9308
# 3399 2400
# 6196561569
# 61 3301-6356
# 3404-5290
# 61 3552-0005 3552-0027
# 3380-2857
# 61 3901-2910 3901-3127
# 6133011116
# 61 3386-1055
# 3301-1561
# 6133012995
# 3399 9300 e 3399 9328
# 6135525557
# 61 3301-1295 3301-284
# 3386-2989
# 61 3301-1561
# 61 3301-6356
# 6133015620
# 3301-3064 3301-6030
# 3386-2989
# 3346 0036
# 61 33972443
# 3346 0603
# 3321-1412
# 61 3224-1634 3321-0769
# 3364 0404
# 61 3526-2001
# 61 3562 8630
# 3453-2727
# 61 3354 1221
# 3244 9999
# 61 32422357
# 61 3369-2788
# 61 33520500
# 61 3435-8833
# 3366-4200
# 3248-4828
# 3346 4030
# 3248 6793
# 61 3568-3850
# (61) 3427-1201
# 3244 0666
# 3443 2089
# 3340-6868
# 3244 1039
# +55 61 32421542
# 3366-8300
# 3488-9200
# 3312 6000
# 3317 4500
# 61 3487-8318
# 61 3488-9837
# 3348 6650 e 3348 6654
# 32455262 32456839
# 3335-9100 e 3335-9128
# 3487 8800 e 3487 8828
# 39101053
# 3442-4300 3442-4328
# 3364 3626 - 3248-4454
# 61 3389-2312 3389-4544
# 3451 3300 e 3451 3328
# 61 3488-9651 3308-4836
# 33838100 33838128
# 99823280
# 3342-1922
# 3364-6017
# 3445 1140 e 3345 3652
# 3399-6621
# 3399-5129/3404-5892
# 2196-7550
# 3399-1234
# 3910-1001
# 3910-1002
# 3910-1003
# 3910-1004
# 3910-1005
# 3910-1006
# 3910-1007
# 3910-1008
# 3910-1009
# 3910-1010
# 3910-1011
# 3910-1012
# 3910-1013
# 3910-1014
# 3910-1015
# 3910-1016
# 3910-1017
# 3910-1018
# 3910-1019
# 3910-1020
# 3910-1021
# 3910-1022
# 3910-1023
# 3910-1024
# 3910-1025
# 3910-1026
# 3910-1027
# 3910-1028
# 3910-1029
# 3910-1030
# 3910-1031
# 3910-1032
# 3910-1033
# 3910-1034
# 3910-1035
# 3910-1036
# 3910-1037
# 3910-1039
# 3910-1040
# 3910-1041
# 3910-1042
# 3910-1043
# 3910-1044
# +55 61 39101045
# 3910-1046
# 3910-1047
# 3910-1048
# 3910-1050
# (61)3233-2496
# 6133334479
# 6133338022
# 6184685267
# 6133330101
# 6133336644
# 6133335666
# 6134341251
# 618510902
# 6134347575
# 6133335722
# 6133580615
# 6141029814
# 6133333218
# 33335588
# 61-3964-0499
# 61-3435-2375
# 61-3797-4155
# 3568-2289
# 61 3383-3900
# 61-3567-1999
# 3567-6595
# (61) 3427-3535
# 61 3451-9752
# 3388-9700
# 3445 5000
# 3369-3149
# +55 61 33688282;+55 61 33688283
# 33106000
# 3443 1003
# +55 61 3445 5900
# 501-1919 E 9616-2212
# 3272-2390 3273-0647
# 3343-1244
# 61 3361-7767
# +55 61 3629 9900
# +55 61 32740591
# +55 61 30479494
# +55 61 33497001
# 3382-4424
# +55 61 32747113
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 30456166
# +55 61 40039846
# +55 61 39668300
# +55 61 38794932
# +556132445797
# +556133490106
# +55 (61) 3107-8901
# +55 61 33269170
# +55 61 39648482
# +55 61 30420202
# +55 61 33268078
# +55 61 81363429
# +55 61 33474913
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 81885338
# +55 61 34478112
# +55 61 30397979
# +55 61 34477494
# +55 61 33262357
# +55(61) 3081-8383
# +55 61 33261135
# +55 61 32722055
# +55 61 33411200
# +55 61 40039846
# +55 61 32739558
# +55 61 32740811
# +55 61 40039846
# +55 61 40039846
# +55 61 33265752
# +55 61 33470173
# + 55 61 3618 1768
# +55 61 30372422
# +55 61 32028882
# 6132558900
# +556133464624
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 99730020
# +55 61 30328004
# 61 86085555
# +55 61 30411029
# +55 61 33406668
# + 55 61 3381-1386
# +55 61 3381-6963 / 3568-4059 / 3381-8212
# +55 61 30361096
# +55 061 31076657
# +55 61 35415670
# +55 61 32990424
# +55 (61) 3242-3532
# (61)9938-0708
# (61) 3042-7249
# 86393500
# +55 61 34682000
# 06184707279
# +55 61 30323100
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 3901 7128
# +55 61 9902 3654
# +55 61 33473985;+55 61 91400303
# +55 61 33473985;+55 61 91400303
# +55 61 33494970
# +556132020220
# +556132721002
# +556135812850
# +556138795969
# +556133401716
# +556134436376
# +556133260302
# +556133261922
# +556132742810
# +556133280332
# +556130336498
# +556133261442
# +556130348909
# +556133279552
# +556133261406
# +556133260801
# +556133549626
# +556185404488
# +556133710517
# +556182357164
# +556133553550
# +556133736696
# +556133731545
# +556192156203
# +556133732040
# +556133721459
# +556130424292
# +556134715420
# +556133586137
# +556133734212
# +556133556034
# +556130462585
# +556139644871
# +556133545022
# +556181552762
# +556133715632
# +556135815584
# +556130473368
# +556184043754
# +556135815727
# +556192576552
# +556185977459
# +556135221689
# +556133544262
# +556130425676
# +556133721400
# +556133466657
# +556184923181
# +55 (61) 3427-4949
# +55 (61) 3335-0222
# +55 61 32740406
# 32263208
# 6133826015
# 61-3028-9700
# +55 61 3369 1600
# 61 35254222
# +55 (61) 98127-3875
# 61 3053-0854
# 39640900
# 6184866256
# 32511818
# +55 61 993721399
# +556135817921
# 6133491332
# 61 32720274
# +55 61 3248 0403
# +55 61 3364 0191
# +55 61 3248 2009
# +55 61 3347 5000
# 06133741110
# 6133463354
# +55 61 33265234
# 6130341623
# +55 61 3244 8984
# 61993892842
# +556135520782
# 6133860886
# +55 61 37037223
# 6136261138
# 556134273729
# +556135413146
# +55 61 32634031
# +55 61 35415569
# +55 61 985923707
# +55 61 33472225
# 3042-1887
# 61993978881
# +55 61 32176800
# (61)37119487
# +55 61 32577611
# +55 61 32547866
# +55 61 32249308
# +55 61 30260800
# +55 61 30212188
# +55 61 32025006
# +55 61 21947737
# +55 61 33561031
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# +55 61 40039846
# (61) 3585-1924
# +55 (61) 3274-0267
# +55 61 33142110
# +55 61 34034747
# 3314 5225
# 61 3348 - 1100
# 0800612007
# (61) 3901-8363
# 61 3213-4000
# +55 (61) 3244-1660
# +55 61 33145225
# 61-3901-7530, 61-3447-8156
# 3272 2948 e 3273 9233
# 3214 4777
# +55 61 33127000
# +55 61 32223999
# +55 61 3443 5500
# +55 61 32429933
# (61) 3426.0400
# +55 61 33403747
# 3245-4555 3245-4611
# 3242 9088
# 3905 8632
# +55 61 3368 7224
# +55 61 3248 1672
# +55 (61) 3427-2101
# (61) 33820094
# +55 61 33610404
# 34353471 34353457
# +55 61 35749700
# +556133889956
# +55 61 3445 5888
# 3394 9349
# +55 61 3340 5545
# 33541838
# +55 61 34272579
# +55 61 34272313
# +55 61 33912822
# +55 61 32238276
# 3393-6361
# +556120246300
# +55 61 32167500
# 3399-5476
# 3399-7186/5440
# 61 35614141
# +55 61 31078901
# 61 34879000
# 6132076521
# 61 3462-8800
# 3395 9100 e 3395 9128
# 6134353002
# 61 3378-9200 3378-9228
# +55 (61) 3107-8901
# +55 61 31078901
# +55 (61) 3107-8901
# +55 (61) 3357-4721
# +55 (61) 3427-4081
# +55 (61) 3427-1512
# +55 (61)3427-2052
# +55 (62) 3981-1192
# (61) 3432-2425
# 61) 3432-2108 / 3981-1149
# (61) 3642-4176
# (61) 3642 1483 / 3981 1150
# +55 61 33690881
# +55 61 32420542
# 3901-7556
# 3901-7559
# 3901 7568
# +55 61 31032226
# +55 61 32134848
# +55 61 30128000
# +55 61 81725233
# +55 61 34454400
# +556133871060
# +556139012924
# 3901 7564
# +55 61 3351 6230
# 3335-9307
# +55 61 3577 5000
# +55 61 39013779
# +55 61 39013789
# +55 61 39013784
# +55 61 34419618;+55 61 34419680
# +55 (61) 3246 9763
# +55 61 3366 2530
# +55 61 3427 4848
# +55 61 3427 1073
# +55 61 3427 2434
# +55 61 32484006;+55 61 32485145
# +55 61 20309851
# 3244 1380
# +55 (61) 3033-3117
# 3319-4400
# defaultdict(<type 'int'>, {'no match': 710, 'match': 52})

# %%
# look for the number of telephone correct pattern on the "k" attribute "alt_phone"
attribute = "alt_phone"
pattern_re = phone_re
print check_patterns(OSM_FILE, attribute, pattern_re)
# Out:
# +55 61 3427 4017
# +55 61 3366 2660
# defaultdict(<type 'int'>, {'no match': 2})

# %%
# look for the number of email correct pattern on the "k" attribute "email"
attribute = "email"
pattern_re = email_re
print check_patterns(OSM_FILE, attribute, pattern_re)
# Out:
# defaultdict(<type 'int'>, {'match': 19})

# %%
# look for the number of email correct pattern on the "k" attribute "contact:email"
attribute = "contact:email"
pattern_re = email_re
print check_patterns(OSM_FILE, attribute, pattern_re)
# Out:
# defaultdict(<type 'int'>, {'match': 2})

# %%
# look for the number of website correct pattern on the "k" attribute "website"
attribute = "website"
pattern_re = site_re
print check_patterns(OSM_FILE, attribute, pattern_re)
# Out:
# www.santander.com.br
# www.felts.com.br
# www.anac.gov.br
# viaesteticabeleza.com.br
# www.photomidia.com.br
# www.zascar.com.br
# www.jjempilhadeiras.com.br
# facebook.com/restaurantemanati
# www.abrapa.com.br
# www.pastelariarossoni.com
# www.estudiomappa.com
# www.planejamento.gov.br
# www.planejamento.gov.br
# www.superadega.com.br
# nacaoaventureira.com.br
# www.felicittashopping.com.br
# www.cartoriocolorado.com.br
# www.cartoriodetaguatinga.com.br
# www.adeb.com.br
# www.icesamambaia.org.br
# defaultdict(<type 'int'>, {'no match': 20, 'match': 346})

# %%
# look for the number of opening hours correct pattern on the "k" attribute "opening_hours"
attribute = "opening_hours"
pattern_re = opening_hours_re
print check_patterns(OSM_FILE, attribute, pattern_re)
# Out:
# 06:00-18:00
# 06:00-20:00
# 18:00-23:00
# 07:00 - 19:30
# Mo-Sa 12:00-15:00,19:00-23:00; Su 12:00-17:00
# 08:00-17:30
# 07:30-18:00
# 08:00-18:00
# Mo-Sa 11:00-15:30;17:00-20:00
# 12:00-15:00
# Mo-Sa 08:00-22:00, Su 08:00-18:00
# Mo-Fr 07:00:21:00; Sa-Do 07:00-20:00
# 17:30-23:30
# 09:00-18:00
# 11:00 - 01:00
# Mo-Sa 11:30-15:30, 18:30-23:30
# 08:00-18:00
# 11:00-15:00
# Mo-Su 08:0-18:00
# 07:00-19:00
# Th 10:00-22:00; Su, Tu-We, Fr 19:00-19:30, 21:00-21:30
# Mo-Fr 06:00-23:00; Sa 08:00-14:00,16:00-20:00; Su 09:00-13:00
# 10:00-22:00
# Mo-Su 11:00-14:00,18:00-22:00
# 08:00-18:00
# 07:30 - 21:30
# 08:00-18:00
# 08:00-18:00
# 08:30-22:30
# 16:00-23:30
# 09:00-17:00
# Su-Mo, Fr 19:00-21:00
# 09:00-17:00
# 08:00 ate´17:30
# mo-mo 16:20 22:00
# Mo-Fr 7:30-23:00;Sa 8:00-14:00
# Seg a Sex de 11:00 às 14:00
# 06:00-22:00
# 09:00-19:00
# 13:00-19:00
# 08:00-18:00
# 07:00-13:30;17:30-22:30
# 07:30-18:30
# 08:00-22:00
# 07:00-23:00
# 08:00 ATÉ 18:00
# Seg à Sex de 08:00 às 20:00
# defaultdict(<type 'int'>, {'no match': 47, 'match': 256})

# %% [markdown]
# ### Find how many unique users have contributed to the map
# ##### Functions
# _from lesson "Case Study: OpenStreetMap Data", "7. Quiz: Investigando Usuários". Adapted_

# %%
def get_attribute(element, tag_attrib):
    """Get attribute value from ET element"""
    
    return element.attrib[tag_attrib]


def get_unique_attribute(filename, tag_attrib):
    """Get a set of unique tag attribute value"""
    
    unique_attrib = set()
    for _, element in ET.iterparse(filename):
        if tag_attrib in element.attrib:
            unique_attrib.add(get_attribute(element, tag_attrib))

    return unique_attrib

# %% [markdown]
# ##### Callers

# %%
# get the user id and the number of unique contribute users on the OSM xml file
user_attrib = 'uid'
users = get_unique_attribute(OSM_FILE, user_attrib)
print "unique contributers: ", len(users)
pprint.pprint(users)
# Out:
# unique contributers:  730
# set(['100064',
#      '1010353',
#      '1016290',
#      '1020923',
#      '102648',
#      '1031962',
#      '103253',
#      '103464',
#      '1039852',
#      '1069176',
#      '107257',
#      '108084',
#      '109705',
#      '1113277',
#      '11374',
#      '1138855',
#      '115579',
#      '118021',
#      '1193351',
#      '1193851',
#      '1196357',
#      '1202866',
#      '1204081',
#      '1206082',
#      '1206540',
#      '1208237',
#      '1208664',
#      '1211056',
#      '121406',
#      '1217944',
#      '1218134',
#      '1227959',
#      '12293',
#      '1231595',
#      '1240849',
#      '124232',
#      '12448',
#      '1249085',
#      '1249205',
#      '1267083',
#      '128186',
#      '12910',
#      '12966',
#      '130065',
#      '130472',
#      '1305259',
#      '1306',
#      '1310899',
#      '13203',
#      '133003',
#      '13413',
#      '1342842',
#      '1342943',
#      '1351096',
#      '1352904',
#      '1363315',
#      '1373505',
#      '1393857',
#      '1420318',
#      '142197',
#      '1426385',
#      '1434429',
#      '144314',
#      '144878',
#      '145231',
#      '1459616',
#      '146016',
#      '148776',
#      '149606',
#      '1497291',
#      '1497579',
#      '149876',
#      '150335',
#      '1517451',
#      '1517653',
#      '152074',
#      '152289',
#      '1554107',
#      '1566468',
#      '15720',
#      '1593814',
#      '1596',
#      '1611',
#      '1615805',
#      '161619',
#      '1624591',
#      '162465',
#      '1650482',
#      '165869',
#      '165898',
#      '1661028',
#      '1679',
#      '1702916',
#      '1705348',
#      '1709892',
#      '1714450',
#      '172061',
#      '1721088',
#      '1722822',
#      '1723120',
#      '1727930',
#      '1728737',
#      '1731253',
#      '17497',
#      '1757396',
#      '1758626',
#      '1766262',
#      '1768070',
#      '1772211',
#      '1772368',
#      '177295',
#      '1778156',
#      '1778799',
#      '1780702',
#      '1783785',
#      '1799899',
#      '1802220',
#      '18069',
#      '181135',
#      '1812556',
#      '1819463',
#      '1819919',
#      '1819940',
#      '1820716',
#      '1824494',
#      '1829683',
#      '1832883',
#      '1833672',
#      '1837699',
#      '1840640',
#      '1852496',
#      '1854688',
#      '1856060',
#      '1862434',
#      '1866562',
#      '1868239',
#      '1872509',
#      '1875614',
#      '1875819',
#      '1897523',
#      '1897686',
#      '1897798',
#      '1897885',
#      '1897986',
#      '1898141',
#      '1898209',
#      '1898542',
#      '1898798',
#      '1898990',
#      '1905980',
#      '1907644',
#      '1918190',
#      '1921990',
#      '1922834',
#      '1931014',
#      '1938595',
#      '1939582',
#      '1945407',
#      '1947412',
#      '19532',
#      '1957870',
#      '1960024',
#      '1962477',
#      '1964232',
#      '1965529',
#      '196617',
#      '1976363',
#      '1976381',
#      '1977988',
#      '1981756',
#      '1981936',
#      '2003751',
#      '2012644',
#      '201359',
#      '2014044',
#      '2021291',
#      '202132',
#      '2023657',
#      '202535',
#      '2025363',
#      '2026260',
#      '2028679',
#      '203388',
#      '203548',
#      '2038133',
#      '2046641',
#      '2057798',
#      '2058176',
#      '205971',
#      '2064685',
#      '2066724',
#      '2082896',
#      '2086005',
#      '2096647',
#      '2097308',
#      '2108025',
#      '2108808',
#      '211182',
#      '2114077',
#      '2114276',
#      '2115749',
#      '212204',
#      '2132301',
#      '2134466',
#      '214210',
#      '215964',
#      '2160962',
#      '216204',
#      '2163061',
#      '2163223',
#      '2173970',
#      '2178867',
#      '2186490',
#      '2191070',
#      '2204237',
#      '2209894',
#      '2219338',
#      '2219985',
#      '2226712',
#      '2242212',
#      '224610',
#      '2257169',
#      '2259198',
#      '2262090',
#      '2269742',
#      '2286286',
#      '2295501',
#      '230234',
#      '2323477',
#      '2336763',
#      '2339960',
#      '2340142',
#      '234873',
#      '2349774',
#      '236361',
#      '2370339',
#      '2370419',
#      '2373958',
#      '23770',
#      '2377377',
#      '237777',
#      '23785',
#      '237976',
#      '2388203',
#      '239998',
#      '2407788',
#      '2436275',
#      '2436679',
#      '2441325',
#      '244353',
#      '2445224',
#      '244754',
#      '24551',
#      '2463592',
#      '2471547',
#      '2496484',
#      '2501008',
#      '2501310',
#      '2507488',
#      '2508151',
#      '2511706',
#      '2512300',
#      '251543',
#      '2515430',
#      '2517553',
#      '2526262',
#      '2537928',
#      '2544205',
#      '2554698',
#      '2555393',
#      '2582707',
#      '2587637',
#      '259819',
#      '2599699',
#      '2607707',
#      '26299',
#      '2634876',
#      '2647840',
#      '26599',
#      '2674662',
#      '26798',
#      '2681818',
#      '2681830',
#      '2683937',
#      '2685168',
#      '2685842',
#      '2694431',
#      '2696727',
#      '2697401',
#      '2701593',
#      '2709441',
#      '27099',
#      '2729903',
#      '2745870',
#      '2748195',
#      '2762547',
#      '2772911',
#      '2792542',
#      '2805063',
#      '2807173',
#      '2818592',
#      '2823295',
#      '28237',
#      '2835928',
#      '2838918',
#      '2838920',
#      '2887562',
#      '2890814',
#      '290680',
#      '2913188',
#      '29261',
#      '293358',
#      '2935804',
#      '2941043',
#      '2963768',
#      '2976322',
#      '2980822',
#      '2992774',
#      '3003653',
#      '300459',
#      '300469',
#      '3009268',
#      '3011478',
#      '3037362',
#      '3044849',
#      '3058851',
#      '3066413',
#      '3081051',
#      '3086718',
#      '3087631',
#      '3087928',
#      '31385',
#      '3147342',
#      '3148831',
#      '3154487',
#      '3167029',
#      '3178375',
#      '3186765',
#      '3186831',
#      '3211415',
#      '3217737',
#      '323266',
#      '3240601',
#      '324215',
#      '328459',
#      '3292252',
#      '3294056',
#      '3296268',
#      '3298168',
#      '3309315',
#      '331548',
#      '333175',
#      '3333069',
#      '3345575',
#      '3348694',
#      '3353039',
#      '3356162',
#      '3361105',
#      '3361201',
#      '3371833',
#      '3381325',
#      '338611',
#      '3390807',
#      '339581',
#      '341069',
#      '3416082',
#      '3445357',
#      '3460982',
#      '3462190',
#      '3462892',
#      '3474347',
#      '347944',
#      '348290',
#      '3492536',
#      '3496454',
#      '3514464',
#      '3516',
#      '3526564',
#      '352940',
#      '3535700',
#      '3551745',
#      '3574914',
#      '3592768',
#      '360183',
#      '360392',
#      '3621507',
#      '3638624',
#      '3644356',
#      '367724',
#      '367813',
#      '3720816',
#      '3745188',
#      '3759483',
#      '3760051',
#      '3777534',
#      '380554',
#      '381205',
#      '381516',
#      '3815195',
#      '3817907',
#      '3843224',
#      '385027',
#      '3852052',
#      '3867271',
#      '3875754',
#      '3877019',
#      '389299',
#      '391110',
#      '3915464',
#      '39457',
#      '39504',
#      '397143',
#      '39774',
#      '3980640',
#      '3985214',
#      '3997818',
#      '4006909',
#      '4013979',
#      '401472',
#      '402624',
#      '4054',
#      '4111565',
#      '411244',
#      '4112693',
#      '4129694',
#      '412993',
#      '413449',
#      '4137743',
#      '4148813',
#      '4151003',
#      '4151558',
#      '4168062',
#      '4194210',
#      '4195058',
#      '419970',
#      '4207699',
#      '421042',
#      '42123',
#      '4215128',
#      '421662',
#      '4220257',
#      '4224163',
#      '4230144',
#      '4231173',
#      '4270768',
#      '4297027',
#      '4304166',
#      '431038',
#      '4313572',
#      '4322391',
#      '4323763',
#      '4328459',
#      '4347495',
#      '4348811',
#      '4352093',
#      '4356270',
#      '436419',
#      '4372514',
#      '4373807',
#      '437598',
#      '4393426',
#      '4411924',
#      '4428417',
#      '443130',
#      '447187',
#      '44759',
#      '447903',
#      '4497052',
#      '4499',
#      '4509368',
#      '4513842',
#      '4514924',
#      '4532493',
#      '4538059',
#      '453989',
#      '4542020',
#      '4556303',
#      '4567793',
#      '4568650',
#      '458314',
#      '4586096',
#      '459384',
#      '4598873',
#      '4612177',
#      '4625163',
#      '4626372',
#      '463504',
#      '463507',
#      '4639521',
#      '4648777',
#      '4648890',
#      '471301',
#      '4718299',
#      '472018',
#      '473680',
#      '474706',
#      '4780825',
#      '4782647',
#      '4797674',
#      '4802',
#      '4810462',
#      '481116',
#      '4812612',
#      '4834697',
#      '483508',
#      '4842185',
#      '4847896',
#      '4849566',
#      '4857259',
#      '48923',
#      '4896388',
#      '4904426',
#      '4907353',
#      '4909889',
#      '4936474',
#      '4950504',
#      '4953948',
#      '4960090',
#      '4981934',
#      '4983338',
#      '5000972',
#      '5006581',
#      '5007166',
#      '5017369',
#      '502691',
#      '503740',
#      '5038158',
#      '5040787',
#      '5049661',
#      '5052207',
#      '5060500',
#      '5061841',
#      '507357',
#      '5080853',
#      '5083533',
#      '5086148',
#      '5088810',
#      '5098623',
#      '510836',
#      '5145774',
#      '5159687',
#      '5160566',
#      '517061',
#      '5183101',
#      '5199135',
#      '5201771',
#      '520239',
#      '5203049',
#      '5210013',
#      '5215340',
#      '524500',
#      '5254226',
#      '5278494',
#      '5278784',
#      '5279558',
#      '52797',
#      '5279844',
#      '5279852',
#      '5282618',
#      '5282843',
#      '5283386',
#      '5285366',
#      '5295137',
#      '53073',
#      '5311643',
#      '5314390',
#      '5317622',
#      '5322974',
#      '532794',
#      '533398',
#      '5346672',
#      '5352007',
#      '5353491',
#      '5354190',
#      '5359',
#      '536117',
#      '5374678',
#      '5379064',
#      '5381252',
#      '53908',
#      '5421301',
#      '5423969',
#      '5427301',
#      '5432646',
#      '5449682',
#      '5468288',
#      '5480696',
#      '549284',
#      '549478',
#      '5498451',
#      '5498728',
#      '5529477',
#      '5538702',
#      '555032',
#      '558957',
#      '559500',
#      '559551',
#      '5621740',
#      '5647152',
#      '5649369',
#      '5655015',
#      '5655684',
#      '5665485',
#      '5665651',
#      '5666168',
#      '567121',
#      '5678861',
#      '56901',
#      '569455',
#      '569772',
#      '5709391',
#      '5732278',
#      '5744576',
#      '574654',
#      '574828',
#      '578108',
#      '5794010',
#      '582148',
#      '584301',
#      '5843286',
#      '585072',
#      '585627',
#      '5870673',
#      '5882736',
#      '589596',
#      '589826',
#      '592501',
#      '593990',
#      '596047',
#      '5991422',
#      '600991',
#      '601072',
#      '6045197',
#      '604619',
#      '6085697',
#      '609753',
#      '609760',
#      '611821',
#      '612881',
#      '613812',
#      '614198',
#      '615851',
#      '6158609',
#      '6159216',
#      '616774',
#      '620948',
#      '6210191',
#      '621545',
#      '6221440',
#      '6236428',
#      '6243516',
#      '6243944',
#      '6265347',
#      '62817',
#      '630782',
#      '63107',
#      '6315906',
#      '6341549',
#      '6349815',
#      '6357947',
#      '6359243',
#      '6359822',
#      '6367402',
#      '6372913',
#      '638224',
#      '6385371',
#      '6409317',
#      '641481',
#      '64212',
#      '644132',
#      '6450381',
#      '64578',
#      '650687',
#      '651813',
#      '651869',
#      '661378',
#      '664287',
#      '675255',
#      '67862',
#      '679801',
#      '69102',
#      '691362',
#      '69259',
#      '696713',
#      '698732',
#      '698879',
#      '705049',
#      '70696',
#      '71025',
#      '710590',
#      '716675',
#      '716772',
#      '718054',
#      '71829',
#      '720872',
#      '722137',
#      '72235',
#      '722644',
#      '7396',
#      '745466',
#      '76933',
#      '788018',
#      '78918',
#      '79543',
#      '79602',
#      '81933',
#      '820665',
#      '82797',
#      '83112',
#      '83162',
#      '8339',
#      '83557',
#      '85218',
#      '879556',
#      '88164',
#      '882114',
#      '883031',
#      '891623',
#      '894121',
#      '898775',
#      '90488',
#      '905424',
#      '915613',
#      '9176',
#      '94578',
#      '946007',
#      '94659',
#      '962387',
#      '994441',
#      '99872'])

# %% [markdown]
# ### Fix "k" values

# %% [markdown]
# ##### Functions

# %%
def replace_value(element, new_value, attribute):
    """Replace element attribute value"""
    
    element.attrib[attribute] = new_value
    return element
            
def fix_osm_k(filename, new_filename, k_mapping, attribute="k", tags=('node', 'way', 'relation')):
    """Update "k" attribute values on a new OSM file"""
    
    with open(new_filename, 'wb') as output:
        output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
        output.write('<osm version="0.6" generator="osmconvert 0.8.5" timestamp="2017-08-10T15:02:03Z">\n  ')

        for _, element in ET.iterparse(filename, events=("end",)):
            if k_mapping["addr:postcode"] in element.attrib.values():
                element = replace_value(element, "addr:postcode", attribute)
            elif k_mapping["email"] in element.attrib.values():
                element = replace_value(element, "email", attribute)
            elif k_mapping["addr:street"] in element.attrib.values():
                element = replace_value(element, "addr:street", attribute)
            
            if element.tag in tags:
                output.write(ET.tostring(element, encoding='utf-8'))
        output.write('</osm>')

# %% [markdown]
# ##### Callers

# %%
# Fix OSM k values on a new file
k_mapping = {"addr:postcode" : "postal_code", "email" : "contact:email", "addr:street" : u"endere\xe7o"}
new_filename = "federal_district_fixed_k.osm"
fix_osm_k(OSM_FILE, new_filename, k_mapping)

# %% [markdown]
# ##### Check the result

# %%
# Check if the old "k" values were updated
for _, element in ET.iterparse(new_filename):
    if "k" in element.attrib:
        if element.attrib["k"] in ("postal_code", "contact:email", u"endere\xe7o"):
            print "old k found: ", element.attrib["k"]

# %% [markdown]
# ### Fix "v" values
# ##### Regular Expressions

# %%
phone_fix_re = re.compile(r'(\+?55? ?\(?61?\)? ?)?(9?\d{4}[-| |\.]*\d{4})')

# %% [markdown]
# ##### Functions

# %%
def fix_postcode(postcode):
    """Apply pattern to the postcode"""
    
    postcode = re.sub(r'[^\d]', '', postcode)
    if len(postcode) == 8:
        postcode = postcode[:5] + '-' + postcode[5:]
    return postcode

def fix_phone(phones):
    """Apply default string to the phone"""
    
    new_phones = ""
    for i, phone in enumerate(phones):
        part_phone = re.sub(r'[^\d]', '', phone[1])
        if part_phone[:4] != "0800": 
            if len(part_phone) == 9:
                part_phone = part_phone[:5] + '-' + part_phone[5:]
            else:
                part_phone = part_phone[:4] + '-' + part_phone[4:]
        
        new_phone = '+55 61 ' + part_phone
        if i == 0:
            new_phones = new_phone
        else:
            new_phones = new_phones + ";" + new_phone        
    return new_phones

def fix_website(website):
    """Apply 'http://www.' to the website string"""
    
    website = re.sub(r'(^(https?://)?(www\.)?)', '', website)
    return 'http://www.' + website
  
def apply_re_search(value, re_test):
    """Check if the regular expression is found on the string"""
    
    m = re_test.search(value)
    if m:
        return True
    else:
        return False
    
           
def fix_osm_v(filename, new_filename, attribute="v", tags=('node', 'way', 'relation')):
    """Update "v" attribute values on a new OSM file"""
    
    with open(new_filename, 'wb') as output:
        output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
        output.write('<osm version="0.6" generator="osmconvert 0.8.5" timestamp="2017-08-10T15:02:03Z">\n  ')

        for _, element in ET.iterparse(filename, events=("end",)):
            if "addr:postcode" in element.attrib.values():
                if not apply_re_search(element.attrib["v"], postal_code_re):
                    element.attrib["v"] = fix_postcode(element.attrib["v"])
            elif "phone" in element.attrib.values():
                m = phone_fix_re.findall(element.attrib["v"])
                if m:
                    element.attrib["v"] = fix_phone(m)
            elif "alt_phone" in element.attrib.values():
                m = phone_fix_re.findall(element.attrib["v"])
                if m:
                    element.attrib["v"] = fix_phone(m)        
            elif "website" in element.attrib.values():
                if not apply_re_search(element.attrib["v"], site_re):
                    element.attrib["v"] = fix_website(element.attrib["v"])
            
            if element.tag in tags:
                output.write(ET.tostring(element, encoding='utf-8'))
        output.write('</osm>')

# %% [markdown]
# ##### Callers

# %%
# Fix OSM v values on a new file
old_filename = "federal_district_fixed_k.osm"
new_filename = "federal_district_fixed_k_v.osm"
fix_osm_v(old_filename, new_filename)

# %% [markdown]
# ##### Check the result

# %%
# look for the number of postal code correct pattern on the "k" attribute "addr:postcode"
attribute = "addr:postcode"
pattern_re = postal_code_re
print check_patterns(new_filename, attribute, pattern_re)
# Out:
# 7086705
# 73088
# 72231
# defaultdict(<type 'int'>, {'no match': 3, 'match': 928})

# %%
# look for the number of telephone correct pattern on the "k" attribute "phone"
attribute = "phone"
pattern_re = phone_re
print check_patterns(new_filename, attribute, pattern_re)
# Out:
# +55 61 08006120
# defaultdict(<type 'int'>, {'no match': 1, 'match': 761})

# %%
# look for the number of telephone correct pattern on the "k" attribute "phone"
attribute = "alt_phone"
pattern_re = phone_re
print check_patterns(new_filename, attribute, pattern_re)
# Out:
# defaultdict(<type 'int'>, {'match': 2})

# %%
# look for the number of website correct pattern on the "k" attribute "website"
attribute = "website"
pattern_re = site_re
print check_patterns(new_filename, attribute, pattern_re)
# Out:
# defaultdict(<type 'int'>, {'match': 366})

# %% [markdown]
# ### Fix Addresses
# ##### Constants

# %%
expected = ['avenida', 'rua', 'quadra', u'condomínio', u'edifício', 'setor', 'companhia']

street_mapping = { 'avenida': 'Avenida', 
                'av': 'Avenida', 
                'av.': 'Avenida',
                'av:': 'Avenida', 
                'rua': 'Rua',
                'r': 'Rua',
                'r.': 'Rua',
                'r:': 'Rua',
                'quadra': 'Quadra',
                'q': 'Quadra',
                'q.': 'Quadra',
                'q:': 'Quadra',
                'qd': 'Quadra',
                'qd.': 'Quadra',
                'qd:': 'Quadra',
                'condominio': u'Condomínio',
                u'condomínio': u'Condomínio',   
                'cond': u'Condomínio',
                'cond.': u'Condomínio',
                'cond:': u'Condomínio',
                'condominio': u'Condomínio',
                'edificio': u'Edifício',
                u'edifício': u'Edifício',
                'ed': u'Edifício',
                'ed.': u'Edifício',
                'ed:': u'Edifício',
                'edificio': u'Edifício',
                'setor': 'Setor',
                'st': 'Setor',
                'st.': 'Setor',
                'st:': 'Setor',
                'companhia': 'Companhia',
                'cia': 'Companhia',
                'cia.': 'Companhia',
                'cia:': 'Companhia'
              }

# %% [markdown]
# ##### Functions
# _from lesson "Case Study: OpenStreetMap Data", "10. Quiz: Melhorando os Nomes de Ruas". Adapted_

# %%
def is_street_name(element):
    """Return true if tag attribute "k" is equal to one of street names attributes"""
    
    return (element.attrib["k"] == "addr:housenumber") or (element.attrib["k"] == "addr:street") \
            or (element.attrib["k"] == "name") or (element.attrib["k"] == "addr:housename") \
            or (element.attrib["k"] == "alt_name")

def update_name(string, name):
    """Replace first word on a string"""
    
    return re.sub(r'^\S+\.?', name, string)

def fix_osm_street(filename, new_filename,tags=('node', 'way', 'relation')):
    """Update street names abbreviations on a new OSM file"""
    
    with open(new_filename, 'wb') as output:
        output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
        output.write('<osm version="0.6" generator="osmconvert 0.8.5" timestamp="2017-08-10T15:02:03Z">\n  ')

        for _, element in ET.iterparse(filename, events=("end",)):
            if is_tag(element):
                if is_street_name(element):
                    street_name = get_street_name(element.attrib["v"]).lower()
                    if street_name in street_mapping:
                        element.attrib["v"] = update_name(element.attrib["v"], street_mapping[street_name])
            
            if element.tag in tags:
                output.write(ET.tostring(element, encoding='utf-8'))
        output.write('</osm>')

# %% [markdown]
# ##### Callers

# %%
# Fix OSM street names on a new file
old_filename = "federal_district_fixed_k_v.osm"
new_filename = "federal_district_fixed.osm"
fix_osm_street(old_filename, new_filename)

# %% [markdown]
# ##### Check the result

# %%
# get the "v" attribute matches occurrences on street abbreviation list by "k" attribute
street_abbr = ['avenida', 'av', 'av.', 'av:', 'rua, ''r', 'r.', 'r:', 'quadra', 'q', 'q.', 'qd', 'qd.', 'qd:', 'condominio', u'condomínio', 'cond', 'cond.', 'cond:', 'edificio', u'edifício', 'ed', 'ed.', 'ed:', 'setor', 'st', 'st.', 'st:', 'companhia', 'cia', 'cia.', 'cia:']
pprint.pprint(dict(audit_street(new_filename, street_abbr)))
# Out:
# {'addr:full': {u'Avenida': 2},
#  'addr:housename': {u'Condom\xednio': 1, u'Edif\xedcio': 52, 'Quadra': 2},
#  'addr:housenumber': {u'Edif\xedcio': 1, 'Quadra': 8},
#  'addr:place': {u'Avenida': 1, 'Setor': 10},
#  'addr:street': {'Avenida': 282,
#                  u'Condom\xednio': 66,
#                  u'Edif\xedcio': 3,
#                  u'Quadra': 354,
#                  'Setor': 19},
#  'addr:suburb': {u'Condom\xednio': 1, 'Setor': 102},
#  'alt_name': {'Avenida': 3,
#               u'Condom\xednio': 3,
#               u'Edif\xedcio': 6,
#               'Quadra': 2,
#               'Setor': 11},
#  'description': {'Condominio': 1, u'Condom\xednio': 1, u'Edif\xedcio': 1},
#  'destination': {'Setor': 1},
#  'from': {'Setor': 2},
#  'leisure': {'quadra': 1},
#  'name': {'Avenida': 1102,
#           'Companhia': 15,
#           u'Condom\xednio': 219,
#           u'Edif\xedcio': 258,
#           'Quadra': 1132,
#           'Setor': 315},
#  'name:pt': {u'Condom\xednio': 4, 'Ed': 1, u'Edif\xedcio': 1, 'Quadra': 1},
#  'note': {'Ed.': 8},
#  'official_name': {u'Condom\xednio': 1,
#                    'Edificio': 1,
#                    u'Edif\xedcio': 1,
#                    u'Setor': 15},
#  'old_name': {'Avenida': 3},
#  'operator': {'Companhia': 1, u'Condom\xednio': 4, 'Setor': 2},
#  'seamark:light:character': {'Q': 2}}

# %% [markdown]
# ### Check postal code consistency

# %% [markdown]
# ##### Functions

# %%
def check_postalcode(postalcode):
    """Check if the postal code is within DF range (70000 to 72799 and 73000 to 73699)"""
    
    postalcode = postalcode.split("-")
    postalcode = int(postalcode[0])
    if not ((postalcode >= 70000 and postalcode <= 72799) or \
        (postalcode >= 73000 and postalcode <= 73699)):
            return postalcode
    
def is_postal(element):
    """Return if tag attribute 'k' is 'addr:postcode'"""
    
    return (element.tag == "tag") and (element.attrib["k"] == "addr:postcode")

def check_consistency(filename):
    """Check postal code consistency"""
    
    postal_code_list = []
    for _, element in ET.iterparse(filename):
        if is_postal(element):
            if check_postalcode(element.attrib["v"]):
                postal_code_list.append(check_postalcode(element.attrib["v"]))
    return postal_code_list

# %% [markdown]
# ##### Callers

# %%
# Assert postal codes within Federal District postal code range
postal_code_consistency = check_consistency(new_filename)
print len(postal_code_consistency)
print postal_code_consistency
# Out:
# 57
# [72880, 72880, 72876, 72876, 72876, 72876, 72910, 72910, 87200, 73803, 73802, 73803, 73802, 73803, 73803, 73803, 73803, 73803, 72878, 7086705, 73803, 73803, 73803, 73809, 73809, 73809, 73809, 73809, 73809, 73809, 73809, 73809, 73809, 73809, 73809, 73809, 73809, 73809, 73809, 73809, 73803, 73803, 73803, 73801, 72870, 73803, 72900, 73803, 73803, 73803, 73803, 73803, 73803, 72878, 72870, 72870, 72878]

# %% [markdown]
# ### Write csv file
# ##### Functions
# _from lesson "Case Study: OpenStreetMap Data", "11. Quiz: Melhorando os Nomes de Ruas". Adapted_

# %% [markdown]
# ##### Constants

# %%
NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

# %%
SCHEMA = schema.schema

# %%
def get_key(string):
    """Get k attribute value separated by the first ':' """
    
    k = string.split(":", 1)
    try:
        k_val = k[1]
        type_val = k[0]
    except:
        k_val = k[0]
        type_val = 'regular'
        
    return k_val, type_val

def shape_tags(element, element_id):
    """Shape "tag" XML tag to Python dict"""
    
    element_dict = {}
    k, type_val = get_key(element.attrib['k'])
    
    element_dict['id'] = int(element_id)
    element_dict['key'] = k
    element_dict['type'] = type_val
    element_dict['value'] = element.attrib['v']
    
    return element_dict


def format_element(element, element_dict, fields):
    """Shape node or way XML element to Python dict"""
    
    for key in element.attrib:
        if key in fields:
            if SCHEMA[element.tag]['schema'][key]['type'] == 'integer':
                element_dict[key] = int(element.attrib[key])
            elif SCHEMA[element.tag]['schema'][key]['type'] == 'float':
                element_dict[key] = float(element.attrib[key])
            elif SCHEMA[element.tag]['schema'][key]['type'] == 'string':
                element_dict[key] = element.attrib[key]
                
    return element_dict

def shape_nd(element, element_id, position):
    """Shape nd XML tag to Python dict"""
    
    element_dict = {}
    
    element_dict['id'] = int(element_id)
    element_dict['node_id'] = int(element.attrib['ref'])
    element_dict['position'] = position
    
    return element_dict

def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS):
    """Shape xml elements to list of dictionaries""" 
    
    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []

    if element.tag == 'node':
        node_attribs = format_element(element, node_attribs, node_attr_fields)
         
        for tag in element:
            if tag.tag == 'tag':
                tags.append(shape_tags(tag, element.attrib['id']))
        
        return {'node': node_attribs, 'node_tags': tags}
    
    elif element.tag == 'way':
        way_attribs = format_element(element, way_attribs, way_attr_fields)
                    
        position = 0
        for tag in element:
            if tag.tag == 'tag':
                tags.append(shape_tags(tag, element.attrib['id']))
                
            if tag.tag == 'nd':
                way_nodes.append(shape_nd(tag, element.attrib['id'], position))                
                position += 1
        
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}


# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)

    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_string = pprint.pformat(errors)
        
        raise Exception(message_string.format(field, error_string))


class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
        codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
        codecs.open(WAYS_PATH, 'w') as ways_file, \
        codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
        codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        #nodes_writer.writeheader()
        #node_tags_writer.writeheader()
        #ways_writer.writeheader()
        #way_nodes_writer.writeheader()
        #way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    if el['node_tags']:
                        node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    if el['way_nodes']:
                        way_nodes_writer.writerows(el['way_nodes'])
                    if el['way_tags']:
                        way_tags_writer.writerows(el['way_tags'])

# %% [markdown]
# ##### Callers

# %%
OSM_PATH = "federal_district_fixed.osm"
process_map(OSM_PATH, validate=False)

# %% [markdown]
# ### Create tables
# ##### Script

# %%
QUERY = """CREATE TABLE nodes (
    id INTEGER PRIMARY KEY NOT NULL,
    lat REAL,
    lon REAL,
    user TEXT,
    uid INTEGER,
    version INTEGER,
    changeset INTEGER,
    timestamp TEXT
);

CREATE TABLE nodes_tags (
    id INTEGER,
    key TEXT,
    value TEXT,
    type TEXT,
    FOREIGN KEY (id) REFERENCES nodes(id)
);

CREATE TABLE ways (
    id INTEGER PRIMARY KEY NOT NULL,
    user TEXT,
    uid INTEGER,
    version TEXT,
    changeset INTEGER,
    timestamp TEXT
);

CREATE TABLE ways_tags (
    id INTEGER NOT NULL,
    key TEXT NOT NULL,
    value TEXT NOT NULL,
    type TEXT,
    FOREIGN KEY (id) REFERENCES ways(id)
);

CREATE TABLE ways_nodes (
    id INTEGER NOT NULL,
    node_id INTEGER NOT NULL,
    position INTEGER NOT NULL,
    FOREIGN KEY (id) REFERENCES ways(id),
    FOREIGN KEY (node_id) REFERENCES nodes(id)
);"""

# %% [markdown]
# ##### Execution

# %%
db = sqlite3.connect("DF_OSM2.db")
c = db.cursor()

# all SQL commands (split on ';')
sqlCommands = QUERY.split(';')

# Execute every command from the input file
for command in sqlCommands:
    try:
        c.execute(command)
    except OperationalError, msg:
        print "Command skipped: ", msg

db.commit()
db.close()

# %% [markdown]
# ### Import csvs on DF_OSM.db
# _Procedure executed on sqlite3 terminal_

# %%
sqlite> .mode csv
sqlite> .import nodes.csv nodes
sqlite> .import nodes_tags.csv nodes_tags
sqlite> .import ways.csv ways
sqlite> .import ways_tags.csv ways_tags
sqlite> .import ways_nodes.csv ways_nodes
